# %% [markdown]
# ## Maestría en Analítica de datos
# ## Materia Big Data
# ## Clase 3 - Parte 2
#
# *   Nombre: José Luis Ariza
# *   Código: 80125197

# %% [markdown]
# # 1.Cargar librerias

# %%
import pandas as pd
import numpy as np
import os
import sqlite3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 2.carga/obtención de **información**

# %%
file_path_csv="/content/drive/MyDrive/Ucentral/2025S2/BigData/Clases/Población_Base_de_Datos_Única_de_Afiliados_BDUA_del_régimen_subsidiado_20251205.csv"
try:
  df=pd.read_csv(file_path_csv)
except FileNotFoundError:
  print(f"El archivo {file_path_csv} no fue encontrado.")
except Exception as e:
  print(f"Ocurrió un error al leer el archivo: {e}")

# %%
pd.set_option("display.max_columns", None)
display(df.head())
# Out:
#       Genero Grupo etario  Código de la entidad Nombre de la entidad  \
# 0   Femenino       15 a 19               EPSS37   NUEVA EPS S.A. -CM
# 1   Femenino       19 a 45               ESS024    COOSALUD EPS S.A.
# 2  Masculino       55 a 60               EPSS37   NUEVA EPS S.A. -CM
# 3   Femenino       50 a 55               EPSS37   NUEVA EPS S.A. -CM
# 4  Masculino       15 a 19               EPSS37   NUEVA EPS S.A. -CM
#
#   Régimen al que pertenece   Tipo de afiliado Estado del afiliado  \
# 0               Subsidiado       BENEFICIARIO              Activo
# 1               Subsidiado       BENEFICIARIO              Activo
# 2               Subsidiado  CABEZA DE FAMILIA              Activo
# 3               Subsidiado       BENEFICIARIO              Activo
# 4               Subsidiado       BENEFICIARIO              Activo
#
#   Condición del beneficiario         Zona de Afiliación Departamento  \
# 0                  NO APLICA                      Rural        VALLE
# 1               DISCAPACIDAD  Urbana-Cabecera Municipal    SANTANDER
# 2                  NO APLICA  Urbana-Cabecera Municipal       BOYACA
# 3                  NO APLICA                      Rural     AMAZONAS
# 4                  NO APLICA                     Urbana    ATLANTICO
#
#      Municipio Nivel del Sisbén Grupo poblacional del afiliado  cantidad
# 0      CARTAGO                1           POBLACIÓN CON SISBEN        15
# 1  BUCARAMANGA                1           POBLACIÓN CON SISBEN         1
# 2      COMBITA                2           POBLACIÓN CON SISBEN         1
# 3      LETICIA                2           POBLACIÓN CON SISBEN         1
# 4      BARANOA                1           POBLACIÓN CON SISBEN        21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239329 entries, 0 to 1239328
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Genero                          1239329 non-null  object
#  1   Grupo etario                    1239329 non-null  object
#  2   Código de la entidad            1239329 non-null  object
#  3   Nombre de la entidad            1239329 non-null  object
#  4   Régimen al que pertenece        1239329 non-null  object
#  5   Tipo de afiliado                1239329 non-null  object
#  6   Estado del afiliado             1239329 non-null  object
#  7   Condición del beneficiario      1239329 non-null  object
#  8   Zona de Afiliación              1239329 non-null  object
#  9   Departamento                    1239329 non-null  object
#  10  Municipio                       1239329 non-null  object
#  11  Nivel del Sisbén                1237638 non-null  object
#  12  Grupo poblacional del afiliado  1221524 non-null  object
#  13  cantidad                        1239329 non-null  int64
# dtypes: int64(1), object(13)
# memory usage: 132.4+ MB

# %%
df.describe()
# Out:
#            cantidad
# count  1.239329e+06
# mean   2.149442e+01
# std    1.852056e+02
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    2.000000e+00
# 75%    9.000000e+00
# max    6.332800e+04

# %% [markdown]
# # 3.ETL

# %%
df['cantidad'] = pd.to_numeric(df['cantidad'], errors='coerce')
df['cantidad'] = df['cantidad'].fillna(0).astype(int)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239329 entries, 0 to 1239328
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Genero                          1239329 non-null  object
#  1   Grupo etario                    1239329 non-null  object
#  2   Código de la entidad            1239329 non-null  object
#  3   Nombre de la entidad            1239329 non-null  object
#  4   Régimen al que pertenece        1239329 non-null  object
#  5   Tipo de afiliado                1239329 non-null  object
#  6   Estado del afiliado             1239329 non-null  object
#  7   Condición del beneficiario      1239329 non-null  object
#  8   Zona de Afiliación              1239329 non-null  object
#  9   Departamento                    1239329 non-null  object
#  10  Municipio                       1239329 non-null  object
#  11  Nivel del Sisbén                1237638 non-null  object
#  12  Grupo poblacional del afiliado  1221524 non-null  object
#  13  cantidad                        1239329 non-null  int64
# dtypes: int64(1), object(13)
# memory usage: 132.4+ MB
# None

# %%
columnas_a_convertir =["Departamento","Municipio","Código de la entidad","Nombre de la entidad","Nivel del Sisbén"]
for columna in columnas_a_convertir:
  if columna in df.columns:
    df[columna]=df[columna].astype(str)

# %% [markdown]
# #4.estadísticas descriptivas

# %%
df['Genero'].value_counts()
# Out:
# Genero
# Masculino    639362
# Femenino     599967
# Name: count, dtype: int64

# %%
df_eps= df.groupby('Nombre de la entidad')['cantidad'].sum()
#calcular porcentaje
total_registros = df['cantidad'].sum()
entidad_porcentaje = (df_eps / total_registros) * 100
resultado_df = pd.DataFrame({'Cantidad de Registros': df_eps, 'Porcentaje': entidad_porcentaje})
resultado_df = resultado_df.sort_values(by='Porcentaje', ascending=False)
display(resultado_df.head())
#display(df_eps.head())
# Out:
#                                                     Cantidad de Registros  \
# Nombre de la entidad
# NUEVA EPS S.A.                                                    5258818
# COOSALUD EPS S.A.                                                 2985334
# ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALU...                2294209
# SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGI...                1578763
# EMSSANAR S.A.S.                                                   1565234
#
#                                                     Porcentaje
# Nombre de la entidad
# NUEVA EPS S.A.                                       19.741305
# COOSALUD EPS S.A.                                    11.206775
# ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALU...    8.612331
# SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGI...    5.926587
# EMSSANAR S.A.S.                                       5.875800

# %% [markdown]
# # 5.creación de BD SQLITE y tablas

# %%
db_path="/content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/DataSets_TMP/SQLITE/dbua.db"
db_dir =os.path.dirname(db_path)
if os.path.exists(db_dir):
  print(f"El directorio {db_dir} existe.")
else:
  os.makedirs(db_dir)
  print(f"El directorio {db_dir} fue creado.")
# Out:
# El directorio /content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/DataSets_TMP/SQLITE existe.

# %%
try:
  conn=sqlite3.connect(db_path)
  cursor=conn.cursor()          #objeto que va a interactiar con la bd (dml/ddl)
  print("conectado")
except sqlite3.Error as e:
  print(f"Error al conectar a la base de datos: {e}")
# Out:
# conectado

# %% [markdown]
# ## 5.1 creando tablas maestras

# %%
cursor.execute('''
CREATE TABLE IF NOT EXISTS Departamento (
    Id_Departamento INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Departamento TEXT UNIQUE NOT NULL
)
''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS Sisben (
    Id_Sisben INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Sisben TEXT UNIQUE NOT NULL
)
''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS Eps (
    codigo_Eps TEXT PRIMARY KEY,
    Nombre_Eps TEXT UNIQUE NOT NULL,
    regimen TEXT
)
''')

# %% [markdown]
# ## 5.2 llenado de tablas maestras

# %%
#funcion para cargar datos en tablas maestras (departamento, sisben, eps)
def cargar_datos_a_tablas_maestras(df,db_path,columna, tabla_destino):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  valores_unicos =df[columna].unique()
  for valor in valores_unicos:
    if(pd.notna(valor)): #ignorar valores NaN
      try:
        cursor.execute(f"INSERT OR IGNORE INTO {tabla_destino} (Nombre_{tabla_destino.replace('_','')}) VALUES (?)", (valor,))
      except sqlite3.Error as e:
        print(f"Error al insertar en la tabla {tabla_destino}: {e}")
        pass
  conn.commit()
  conn.close()

# %%
cargar_datos_a_tablas_maestras(df,db_path,"Departamento","Departamento")
cargar_datos_a_tablas_maestras(df,db_path,"Nivel del Sisbén","Sisben")

# %%
def revisar_contenido_de_una_tabla(tabla_nombre, whereColumna='',whereValor='', limit=10, order_by_columna=None, order_asc=True):
  conn=sqlite3.connect(db_path)
  cursor=conn.cursor()
  cursor.execute("SELECT COUNT(*) FROM "+tabla_nombre)
  total_registros=cursor.fetchone()[0]
  print(f"Total de registros en la tabla {tabla_nombre}: {total_registros}")
  sql="SELECT * FROM "+tabla_nombre
  params = ()
  if len(whereColumna)>0:
    sql+=" WHERE "+whereColumna+"=?"
    params = (whereValor,)
  if(order_by_columna):
    orderbyTipo="ASC" if order_asc else "DESC"
    sql+=f" ORDER BY {order_by_columna} {orderbyTipo}"
  sql+=" LIMIT "+str(limit)
  print(sql)
  cursor.execute(sql, params)
  resultados=cursor.fetchall()
  for fila in resultados:
    print(fila)
  conn.close()

# %%
revisar_contenido_de_una_tabla("Departamento",'','',100,'Id_departamento')
# Out:
# Total de registros en la tabla Departamento: 33
# SELECT * FROM Departamento ORDER BY Id_departamento ASC LIMIT 100
# (1, 'VALLE')
# (2, 'SANTANDER')
# (3, 'BOYACA')
# (4, 'AMAZONAS')
# (5, 'ATLANTICO')
# (6, 'ARAUCA')
# (7, 'TOLIMA')
# (8, 'RISARALDA')
# (9, 'HUILA')
# (10, 'CALDAS')
# (11, 'CESAR')
# (12, 'SUCRE')
# (13, 'CORDOBA')
# (14, 'NORTE DE SANTANDER')
# (15, 'META')
# (16, 'CUNDINAMARCA')
# (17, 'ANTIOQUIA')
# (18, 'CAUCA')
# (19, 'CASANARE')
# (20, 'NARINO')
# (21, 'PUTUMAYO')
# (22, 'MAGDALENA')
# (23, 'BOGOTA D.C.')
# (24, 'LA GUAJIRA')
# (25, 'CHOCO')
# (26, 'BOLIVAR')
# (27, 'QUINDIO')
# (28, 'CAQUETA')
# (29, 'VAUPES')
# (30, 'GUAVIARE')
# (31, 'GUAINIA')
# (32, 'VICHADA')
# (33, 'SAN ANDRES')

# %%
revisar_contenido_de_una_tabla("Sisben",'','',100,'nombre_sisben')
# Out:
# Total de registros en la tabla Sisben: 11
# SELECT * FROM Sisben ORDER BY nombre_sisben ASC LIMIT 100
# (8, '0')
# (1, '1')
# (2, '2')
# (10, '3')
# (11, '4')
# (4, 'A')
# (9, 'B')
# (5, 'C')
# (3, 'N')
# (7, 'O')
# (6, 'nan')

# %% [markdown]
# ## 5.3 tabla hija "municipio"

# %%
cursor.execute('''
CREATE TABLE IF NOT EXISTS Municipio (
    Id_Municipio INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Municipio TEXT NOT NULL,
    Id_Departamento INTEGER,
    FOREIGN KEY (Id_Departamento) REFERENCES Departamento(Id_Departamento),
    UNIQUE (Nombre_Municipio, Id_Departamento)
)
''')
conn.commit()
conn.close()

# %%
#para cada municipio buscarle su departamento
def cargar_municipios(df,pd_path):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  tot_creados=0
  for index,row in df.iterrows():
    departamento  =row['Departamento']
    municipio     =row['Municipio']
    cursor.execute("SELECT Id_Departamento FROM Departamento WHERE Nombre_Departamento=?", (departamento,))
    departamento_id=cursor.fetchone()
    if departamento_id:
      departamento_id=departamento_id[0]
      try:
        cursor.execute("INSERT OR IGNORE INTO Municipio (Nombre_Municipio, Id_Departamento) VALUES (?, ?)", (municipio, departamento_id))
        tot_creados+=1
        print(f"creado {tot_creados} => {municipio} en el dpto {departamento} ")
      except sqlite3.sqlite3.IntegrityError:
        pass
    else:
      print(f"ERRROR: Departamento {departamento} para el municipio {municipio} no encontrado")
  conn.commit()
  conn.close()

# %%
cargar_municipios(df,db_path)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# creado 1234330 => SOGAMOSO en el dpto BOYACA
# creado 1234331 => PUERTO LIBERTADOR en el dpto CORDOBA
# creado 1234332 => CUMARIBO en el dpto VICHADA
# creado 1234333 => CALDAS en el dpto ANTIOQUIA
# creado 1234334 => CALARCA en el dpto QUINDIO
# creado 1234335 => ITSMINA en el dpto CHOCO
# creado 1234336 => SILVANIA en el dpto CUNDINAMARCA
# creado 1234337 => SANTA MARTA en el dpto MAGDALENA
# creado 1234338 => TIQUISIO en el dpto BOLIVAR
# creado 1234339 => URIBIA en el dpto LA GUAJIRA
# creado 1234340 => CARTAGENA en el dpto BOLIVAR
# creado 1234341 => TUQUERRES en el dpto NARINO
# creado 1234342 => ORITO en el dpto PUTUMAYO
# creado 1234343 => COLOSO en el dpto SUCRE
# creado 1234344 => LORICA en el dpto CORDOBA
# creado 1234345 => PUERTO LIBERTADOR en el dpto CORDOBA
# creado 1234346 => AGUAZUL en el dpto CASANARE
# creado 1234347 => CALIMA en el dpto VALLE
# creado 1234348 => BETULIA en el dpto ANTIOQUIA
# creado 1234349 => CAJIBIO en el dpto CAUCA
# creado 1234350 => GIRARDOTA en el dpto ANTIOQUIA
# creado 1234351 => ARAUCA en el dpto ARAUCA
# creado 1234352 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 1234353 => YOPAL en el dpto CASANARE
# creado 1234354 => VENTAQUEMADA en el dpto BOYACA
# creado 1234355 => FACATATIVA en el dpto CUNDINAMARCA
# creado 1234356 => LA DORADA en el dpto CALDAS
# creado 1234357 => LIBANO en el dpto TOLIMA
# creado 1234358 => SALADOBLANCO en el dpto HUILA
# creado 1234359 => SAN LUIS DE GACENO en el dpto BOYACA
# creado 1234360 => MALAMBO en el dpto ATLANTICO
# creado 1234361 => PALESTINA en el dpto HUILA
# creado 1234362 => BURITICA en el dpto ANTIOQUIA
# creado 1234363 => MANAURE en el dpto LA GUAJIRA
# creado 1234364 => PUERRES en el dpto NARINO
# creado 1234365 => CALARCA en el dpto QUINDIO
# creado 1234366 => CHITAGA en el dpto NORTE DE SANTANDER
# creado 1234367 => GALAN en el dpto SANTANDER
# creado 1234368 => CAQUEZA en el dpto CUNDINAMARCA
# creado 1234369 => CAREPA en el dpto ANTIOQUIA
# creado 1234370 => TULUA en el dpto VALLE
# creado 1234371 => CAREPA en el dpto ANTIOQUIA
# creado 1234372 => LA CELIA en el dpto RISARALDA
# creado 1234373 => TRUJILLO en el dpto VALLE
# creado 1234374 => SAN LUIS DE GACENO en el dpto BOYACA
# creado 1234375 => PASCA en el dpto CUNDINAMARCA
# creado 1234376 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1234377 => SOLEDAD en el dpto ATLANTICO
# creado 1234378 => CALAMAR en el dpto BOLIVAR
# creado 1234379 => ZAPAYAN en el dpto MAGDALENA
# creado 1234380 => SAN PELAYO en el dpto CORDOBA
# creado 1234381 => SAN PEDRO en el dpto ANTIOQUIA
# creado 1234382 => RIO VIEJO en el dpto BOLIVAR
# creado 1234383 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1234384 => AGUACHICA en el dpto CESAR
# creado 1234385 => SATIVANORTE en el dpto BOYACA
# creado 1234386 => JAMUNDI en el dpto VALLE
# creado 1234387 => OSPINA en el dpto NARINO
# creado 1234388 => LA CEJA en el dpto ANTIOQUIA
# creado 1234389 => SALENTO en el dpto QUINDIO
# creado 1234390 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1234391 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1234392 => BELLO en el dpto ANTIOQUIA
# creado 1234393 => ARMENIA en el dpto QUINDIO
# creado 1234394 => CARTAGENA DEL CHAIRA en el dpto CAQUETA
# creado 1234395 => EL PEÑON en el dpto SANTANDER
# creado 1234396 => GALAPA en el dpto ATLANTICO
# creado 1234397 => CUNDAY en el dpto TOLIMA
# creado 1234398 => BUGA en el dpto VALLE
# creado 1234399 => CHIGORODO en el dpto ANTIOQUIA
# creado 1234400 => FONSECA en el dpto LA GUAJIRA
# creado 1234401 => CHIMA en el dpto CORDOBA
# creado 1234402 => LORICA en el dpto CORDOBA
# creado 1234403 => TENERIFE en el dpto MAGDALENA
# creado 1234404 => CAUCASIA en el dpto ANTIOQUIA
# creado 1234405 => EL CALVARIO en el dpto META
# creado 1234406 => SALDAÑA en el dpto TOLIMA
# creado 1234407 => PLATO en el dpto MAGDALENA
# creado 1234408 => SAN ONOFRE en el dpto SUCRE
# creado 1234409 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1234410 => FALAN en el dpto TOLIMA
# creado 1234411 => YARUMAL en el dpto ANTIOQUIA
# creado 1234412 => SANTA SOFIA en el dpto BOYACA
# creado 1234413 => CHIMICHAGUA en el dpto CESAR
# creado 1234414 => MOSQUERA en el dpto CUNDINAMARCA
# creado 1234415 => AGUADAS en el dpto CALDAS
# creado 1234416 => PITAL en el dpto HUILA
# creado 1234417 => SUCRE en el dpto SUCRE
# creado 1234418 => PALMIRA en el dpto VALLE
# creado 1234419 => UBALA en el dpto CUNDINAMARCA
# creado 1234420 => TELLO en el dpto HUILA
# creado 1234421 => ARATOCA en el dpto SANTANDER
# creado 1234422 => APIA en el dpto RISARALDA
# creado 1234423 => PESCA en el dpto BOYACA
# creado 1234424 => PURACE en el dpto CAUCA
# creado 1234425 => SANTIAGO DE CALI en el dpto VALLE
# creado 1234426 => BARRANQUILLA en el dpto ATLANTICO
# creado 1234427 => ARBOLEDAS en el dpto NORTE DE SANTANDER
# creado 1234428 => RIOHACHA en el dpto LA GUAJIRA
# creado 1234429 => MAGANGUE en el dpto BOLIVAR
# creado 1234430 => GUAMO en el dpto TOLIMA
# creado 1234431 => BUENAVISTA en el dpto SUCRE
# creado 1234432 => COROZAL en el dpto SUCRE
# creado 1234433 => BARBACOAS en el dpto NARINO
# creado 1234434 => SABANALARGA en el dpto ATLANTICO
# creado 1234435 => CARMEN DEL DARIEN en el dpto CHOCO
# creado 1234436 => GRANADA en el dpto META
# creado 1234437 => DIBULLA en el dpto LA GUAJIRA
# creado 1234438 => SANTIAGO DE CALI en el dpto VALLE
# creado 1234439 => DABEIBA en el dpto ANTIOQUIA
# creado 1234440 => YOPAL en el dpto CASANARE
# creado 1234441 => RIOBLANCO en el dpto TOLIMA
# creado 1234442 => ANSERMA en el dpto CALDAS
# creado 1234443 => HATO COROZAL en el dpto CASANARE
# creado 1234444 => LINARES en el dpto NARINO
# creado 1234445 => LA PAZ  ROBLES en el dpto CESAR
# creado 1234446 => PROVIDENCIA en el dpto NARINO
# creado 1234447 => MAJAGUAL en el dpto SUCRE
# creado 1234448 => PONEDERA en el dpto ATLANTICO
# creado 1234449 => PITALITO en el dpto HUILA
# creado 1234450 => GUAMO en el dpto TOLIMA
# creado 1234451 => LA VICTORIA en el dpto VALLE
# creado 1234452 => FUNDACION en el dpto MAGDALENA
# creado 1234453 => CASTILLA LA NUEVA en el dpto META
# creado 1234454 => PUERTO BOYACA en el dpto BOYACA
# creado 1234455 => SANTIAGO DE CALI en el dpto VALLE
# creado 1234456 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 1234457 => VILLA DEL ROSARIO en el dpto NORTE DE SANTANDER
# creado 1234458 => EL TARRA en el dpto NORTE DE SANTANDER
# creado 1234459 => TALAIGUA NUEVO en el dpto BOLIVAR
# creado 1234460 => ARACATACA en el dpto MAGDALENA
# creado 1234461 => GALERAS en el dpto SUCRE
# creado 1234462 => SUESCA en el dpto CUNDINAMARCA
# creado 1234463 => ARATOCA en el dpto SANTANDER
# creado 1234464 => SAN PABLO en el dpto BOLIVAR
# creado 1234465 => SANTUARIO en el dpto ANTIOQUIA
# creado 1234466 => SALDAÑA en el dpto TOLIMA
# creado 1234467 => FILADELFIA en el dpto CALDAS
# creado 1234468 => GENOVA en el dpto QUINDIO
# creado 1234469 => MOCOA en el dpto PUTUMAYO
# creado 1234470 => RICAURTE en el dpto CUNDINAMARCA
# creado 1234471 => CUMBAL en el dpto NARINO
# creado 1234472 => CAMPO DE LA CRUZ en el dpto ATLANTICO
# creado 1234473 => LORICA en el dpto CORDOBA
# creado 1234474 => RECETOR en el dpto CASANARE
# creado 1234475 => PITAL en el dpto HUILA
# creado 1234476 => NECOCLI en el dpto ANTIOQUIA
# creado 1234477 => SINCE en el dpto SUCRE
# creado 1234478 => EL PEÑOL en el dpto CUNDINAMARCA
# creado 1234479 => ARJONA en el dpto BOLIVAR
# creado 1234480 => CHINCHINA en el dpto CALDAS
# creado 1234481 => CALDAS en el dpto ANTIOQUIA
# creado 1234482 => VALLEDUPAR en el dpto CESAR
# creado 1234483 => CONCORDIA en el dpto MAGDALENA
# creado 1234484 => LA ESTRELLA en el dpto ANTIOQUIA
# creado 1234485 => EL CERRITO en el dpto VALLE
# creado 1234486 => LA CUMBRE en el dpto VALLE
# creado 1234487 => MAGANGUE en el dpto BOLIVAR
# creado 1234488 => ESPINAL en el dpto TOLIMA
# creado 1234489 => SAN FERNANDO en el dpto BOLIVAR
# creado 1234490 => SAMANA en el dpto CALDAS
# creado 1234491 => SAN PEDRO DE URABA en el dpto ANTIOQUIA
# creado 1234492 => PATIA (EL BORDO) en el dpto CAUCA
# creado 1234493 => COVEÑAS en el dpto SUCRE
# creado 1234494 => LA PAZ  ROBLES en el dpto CESAR
# creado 1234495 => MUTATA en el dpto ANTIOQUIA
# creado 1234496 => IQUIRA en el dpto HUILA
# creado 1234497 => SAN ANTONIO en el dpto TOLIMA
# creado 1234498 => ARBELAEZ en el dpto CUNDINAMARCA
# creado 1234499 => ACACIAS en el dpto META
# creado 1234500 => SILVANIA en el dpto CUNDINAMARCA
# creado 1234501 => GUADALUPE en el dpto HUILA
# creado 1234502 => SAN JUAN DE ARAMA en el dpto META
# creado 1234503 => BUCARAMANGA en el dpto SANTANDER
# creado 1234504 => EL CASTILLO en el dpto META
# creado 1234505 => TIMBIQUI en el dpto CAUCA
# creado 1234506 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 1234507 => LA TEBAIDA en el dpto QUINDIO
# creado 1234508 => TUQUERRES en el dpto NARINO
# creado 1234509 => SACAMA en el dpto CASANARE
# creado 1234510 => CLEMENCIA en el dpto BOLIVAR
# creado 1234511 => SOACHA en el dpto CUNDINAMARCA
# creado 1234512 => MUTISCUA en el dpto NORTE DE SANTANDER
# creado 1234513 => VALLE DE SAN JOSE en el dpto SANTANDER
# creado 1234514 => EL ZULIA en el dpto NORTE DE SANTANDER
# creado 1234515 => EL PASO en el dpto CESAR
# creado 1234516 => PUPIALES en el dpto NARINO
# creado 1234517 => REMEDIOS en el dpto ANTIOQUIA
# creado 1234518 => VALLEDUPAR en el dpto CESAR
# creado 1234519 => SOPO en el dpto CUNDINAMARCA
# creado 1234520 => MONTERIA en el dpto CORDOBA
# creado 1234521 => CLEMENCIA en el dpto BOLIVAR
# creado 1234522 => SAN JUANITO en el dpto META
# creado 1234523 => PEREIRA en el dpto RISARALDA
# creado 1234524 => PALERMO en el dpto HUILA
# creado 1234525 => VISTA HERMOSA en el dpto META
# creado 1234526 => CHIA en el dpto CUNDINAMARCA
# creado 1234527 => POTOSI en el dpto NARINO
# creado 1234528 => TANGUA en el dpto NARINO
# creado 1234529 => PUERTO GUZMAN en el dpto PUTUMAYO
# creado 1234530 => FUNDACION en el dpto MAGDALENA
# creado 1234531 => LA UNION en el dpto VALLE
# creado 1234532 => BELLO en el dpto ANTIOQUIA
# creado 1234533 => POPAYAN en el dpto CAUCA
# creado 1234534 => GACHETA en el dpto CUNDINAMARCA
# creado 1234535 => LA VIRGINIA en el dpto RISARALDA
# creado 1234536 => LA FLORIDA en el dpto NARINO
# creado 1234537 => BUENAVENTURA en el dpto VALLE
# creado 1234538 => VALLE DE SAN JUAN en el dpto TOLIMA
# creado 1234539 => LA MESA en el dpto CUNDINAMARCA
# creado 1234540 => ANAPOIMA en el dpto CUNDINAMARCA
# creado 1234541 => TULUA en el dpto VALLE
# creado 1234542 => JUNIN en el dpto CUNDINAMARCA
# creado 1234543 => MARMATO en el dpto CALDAS
# creado 1234544 => GUAMO en el dpto TOLIMA
# creado 1234545 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 1234546 => ICONONZO en el dpto TOLIMA
# creado 1234547 => SAN BERNARDO en el dpto NARINO
# creado 1234548 => GONZALEZ en el dpto CESAR
# creado 1234549 => SANTA MARIA en el dpto HUILA
# creado 1234550 => NUQUI en el dpto CHOCO
# creado 1234551 => SARDINATA en el dpto NORTE DE SANTANDER
# creado 1234552 => ANGELOPOLIS en el dpto ANTIOQUIA
# creado 1234553 => SAN EDUARDO en el dpto BOYACA
# creado 1234554 => ALBANIA en el dpto LA GUAJIRA
# creado 1234555 => BARRANQUILLA en el dpto ATLANTICO
# creado 1234556 => RIOHACHA en el dpto LA GUAJIRA
# creado 1234557 => ARACATACA en el dpto MAGDALENA
# creado 1234558 => BUCARAMANGA en el dpto SANTANDER
# creado 1234559 => CAMPOALEGRE en el dpto HUILA
# creado 1234560 => FRANCIS PIZARRO en el dpto NARINO
# creado 1234561 => SAN ROQUE en el dpto ANTIOQUIA
# creado 1234562 => ARAUCA en el dpto ARAUCA
# creado 1234563 => MARQUETALIA en el dpto CALDAS
# creado 1234564 => HONDA en el dpto TOLIMA
# creado 1234565 => VERGARA en el dpto CUNDINAMARCA
# creado 1234566 => CALAMAR en el dpto BOLIVAR
# creado 1234567 => MARINILLA en el dpto ANTIOQUIA
# creado 1234568 => SANTIAGO DE CALI en el dpto VALLE
# creado 1234569 => GUADALUPE en el dpto HUILA
# creado 1234570 => VALLEDUPAR en el dpto CESAR
# creado 1234571 => SANTA CATALINA en el dpto BOLIVAR
# creado 1234572 => LA PEÑA en el dpto CUNDINAMARCA
# creado 1234573 => TANGUA en el dpto NARINO
# creado 1234574 => ATACO en el dpto TOLIMA
# creado 1234575 => CLEMENCIA en el dpto BOLIVAR
# creado 1234576 => LA UNION en el dpto NARINO
# creado 1234577 => SOACHA en el dpto CUNDINAMARCA
# creado 1234578 => CIMITARRA en el dpto SANTANDER
# creado 1234579 => PACORA en el dpto CALDAS
# creado 1234580 => BUGA en el dpto VALLE
# creado 1234581 => PEÑOL en el dpto ANTIOQUIA
# creado 1234582 => LETICIA en el dpto AMAZONAS
# creado 1234583 => SOACHA en el dpto CUNDINAMARCA
# creado 1234584 => TAMARA en el dpto CASANARE
# creado 1234585 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 1234586 => LA CEJA en el dpto ANTIOQUIA
# creado 1234587 => PUEBLOVIEJO en el dpto MAGDALENA
# creado 1234588 => SUPATA en el dpto CUNDINAMARCA
# creado 1234589 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 1234590 => SABANA DE SAN ANGEL en el dpto MAGDALENA
# creado 1234591 => SOPO en el dpto CUNDINAMARCA
# creado 1234592 => PASTO en el dpto NARINO
# creado 1234593 => ITAGUI en el dpto ANTIOQUIA
# creado 1234594 => LIBANO en el dpto TOLIMA
# creado 1234595 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1234596 => RICAURTE en el dpto NARINO
# creado 1234597 => GAMARRA en el dpto CESAR
# creado 1234598 => ELIAS en el dpto HUILA
# creado 1234599 => MIRAFLORES en el dpto BOYACA
# creado 1234600 => AMAGA en el dpto ANTIOQUIA
# creado 1234601 => SANTA ROSA en el dpto BOLIVAR
# creado 1234602 => LA MACARENA en el dpto META
# creado 1234603 => CERETE en el dpto CORDOBA
# creado 1234604 => LA TEBAIDA en el dpto QUINDIO
# creado 1234605 => CHIMICHAGUA en el dpto CESAR
# creado 1234606 => CUBARA en el dpto BOYACA
# creado 1234607 => ACHI en el dpto BOLIVAR
# creado 1234608 => YARUMAL en el dpto ANTIOQUIA
# creado 1234609 => JERUSALEN en el dpto CUNDINAMARCA
# creado 1234610 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 1234611 => DUITAMA en el dpto BOYACA
# creado 1234612 => VALLEDUPAR en el dpto CESAR
# creado 1234613 => ANOLAIMA en el dpto CUNDINAMARCA
# creado 1234614 => SAN MIGUEL en el dpto PUTUMAYO
# creado 1234615 => EL PAUJIL en el dpto CAQUETA
# creado 1234616 => GUATAQUI en el dpto CUNDINAMARCA
# creado 1234617 => PURISIMA en el dpto CORDOBA
# creado 1234618 => PUERTO TRIUNFO en el dpto ANTIOQUIA
# creado 1234619 => INIRIDA en el dpto GUAINIA
# creado 1234620 => AGUAZUL en el dpto CASANARE
# creado 1234621 => SANTA CATALINA en el dpto BOLIVAR
# creado 1234622 => DISTRACCION en el dpto LA GUAJIRA
# creado 1234623 => IPIALES en el dpto NARINO
# creado 1234624 => QUIMBAYA en el dpto QUINDIO
# creado 1234625 => TAME en el dpto ARAUCA
# creado 1234626 => SAN FRANCISCO en el dpto ANTIOQUIA
# creado 1234627 => TAME en el dpto ARAUCA
# creado 1234628 => ANDALUCIA en el dpto VALLE
# creado 1234629 => DIBULLA en el dpto LA GUAJIRA
# creado 1234630 => ZAPATOCA en el dpto SANTANDER
# creado 1234631 => SEVILLA en el dpto VALLE
# creado 1234632 => ANZA en el dpto ANTIOQUIA
# creado 1234633 => BOLIVAR en el dpto CAUCA
# creado 1234634 => EL PIJI¥O DEL CARMEN en el dpto MAGDALENA
# creado 1234635 => VILLAGARZON en el dpto PUTUMAYO
# creado 1234636 => LA JAGUA DE IBIRICO en el dpto CESAR
# creado 1234637 => SAN JOSE DE URE en el dpto CORDOBA
# creado 1234638 => TIMANA en el dpto HUILA
# creado 1234639 => ARBOLETES en el dpto ANTIOQUIA
# creado 1234640 => YUMBO en el dpto VALLE
# creado 1234641 => SUSA en el dpto CUNDINAMARCA
# creado 1234642 => OCAMONTE en el dpto SANTANDER
# creado 1234643 => GONZALEZ en el dpto CESAR
# creado 1234644 => TAME en el dpto ARAUCA
# creado 1234645 => ARAUCA en el dpto ARAUCA
# creado 1234646 => CAICEDONIA en el dpto VALLE
# creado 1234647 => UNION PANAMERICANA en el dpto CHOCO
# creado 1234648 => HATONUEVO en el dpto LA GUAJIRA
# creado 1234649 => PEQUE en el dpto ANTIOQUIA
# creado 1234650 => FILANDIA en el dpto QUINDIO
# creado 1234651 => RIVERA en el dpto HUILA
# creado 1234652 => MONTELIBANO en el dpto CORDOBA
# creado 1234653 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1234654 => CABRERA en el dpto CUNDINAMARCA
# creado 1234655 => PAIME en el dpto CUNDINAMARCA
# creado 1234656 => SIBATE en el dpto CUNDINAMARCA
# creado 1234657 => MIRAFLORES en el dpto BOYACA
# creado 1234658 => GUAMO en el dpto TOLIMA
# creado 1234659 => SESQUILE en el dpto CUNDINAMARCA
# creado 1234660 => LA PAZ  ROBLES en el dpto CESAR
# creado 1234661 => VEGACHI en el dpto ANTIOQUIA
# creado 1234662 => BUGA en el dpto VALLE
# creado 1234663 => MEDELLIN en el dpto ANTIOQUIA
# creado 1234664 => CHIA en el dpto CUNDINAMARCA
# creado 1234665 => SOPETRAN en el dpto ANTIOQUIA
# creado 1234666 => GIRON en el dpto SANTANDER
# creado 1234667 => SALGAR en el dpto ANTIOQUIA
# creado 1234668 => PUERTO RICO en el dpto META
# creado 1234669 => RIO VIEJO en el dpto BOLIVAR
# creado 1234670 => UNION PANAMERICANA en el dpto CHOCO
# creado 1234671 => FLORIDABLANCA en el dpto SANTANDER
# creado 1234672 => UBATE en el dpto CUNDINAMARCA
# creado 1234673 => DOS QUEBRADAS en el dpto RISARALDA
# creado 1234674 => CAMPO DE LA CRUZ en el dpto ATLANTICO
# creado 1234675 => PALMIRA en el dpto VALLE
# creado 1234676 => ARENAL en el dpto BOLIVAR
# creado 1234677 => SAN FRANCISCO en el dpto PUTUMAYO
# creado 1234678 => BELTRAN en el dpto CUNDINAMARCA
# creado 1234679 => TIERRALTA en el dpto CORDOBA
# creado 1234680 => PINCHOTE en el dpto SANTANDER
# creado 1234681 => GUATAVITA en el dpto CUNDINAMARCA
# creado 1234682 => BRICEÑO en el dpto ANTIOQUIA
# creado 1234683 => ALBAN en el dpto NARINO
# creado 1234684 => VIOTA en el dpto CUNDINAMARCA
# creado 1234685 => TURBO en el dpto ANTIOQUIA
# creado 1234686 => ENTRERRIOS en el dpto ANTIOQUIA
# creado 1234687 => SANTA MARIA en el dpto HUILA
# creado 1234688 => LA LLANADA en el dpto NARINO
# creado 1234689 => LA APARTADA en el dpto CORDOBA
# creado 1234690 => SUPIA en el dpto CALDAS
# creado 1234691 => FUNDACION en el dpto MAGDALENA
# creado 1234692 => MANIZALES en el dpto CALDAS
# creado 1234693 => TAUSA en el dpto CUNDINAMARCA
# creado 1234694 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 1234695 => SAN GIL en el dpto SANTANDER
# creado 1234696 => SAN EDUARDO en el dpto BOYACA
# creado 1234697 => VALLEDUPAR en el dpto CESAR
# creado 1234698 => ALBAN en el dpto NARINO
# creado 1234699 => EL PIÑON en el dpto MAGDALENA
# creado 1234700 => BARANOA en el dpto ATLANTICO
# creado 1234701 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1234702 => PASTO en el dpto NARINO
# creado 1234703 => EL DONCELLO en el dpto CAQUETA
# creado 1234704 => ORITO en el dpto PUTUMAYO
# creado 1234705 => BECERRIL en el dpto CESAR
# creado 1234706 => MADRID en el dpto CUNDINAMARCA
# creado 1234707 => MARGARITA en el dpto BOLIVAR
# creado 1234708 => DIBULLA en el dpto LA GUAJIRA
# creado 1234709 => PINILLOS en el dpto BOLIVAR
# creado 1234710 => GUACARI en el dpto VALLE
# creado 1234711 => GUATAVITA en el dpto CUNDINAMARCA
# creado 1234712 => PAICOL en el dpto HUILA
# creado 1234713 => NUNCHIA en el dpto CASANARE
# creado 1234714 => VERGARA en el dpto CUNDINAMARCA
# creado 1234715 => LA PLATA en el dpto HUILA
# creado 1234716 => FLORIDA en el dpto VALLE
# creado 1234717 => ARGELIA en el dpto CAUCA
# creado 1234718 => CONDOTO en el dpto CHOCO
# creado 1234719 => MONTERIA en el dpto CORDOBA
# creado 1234720 => SABANA DE SAN ANGEL en el dpto MAGDALENA
# creado 1234721 => VALPARAISO en el dpto CAQUETA
# creado 1234722 => QUINCHIA en el dpto RISARALDA
# creado 1234723 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 1234724 => CUNDAY en el dpto TOLIMA
# creado 1234725 => SAN MARCOS en el dpto SUCRE
# creado 1234726 => GUAVATA en el dpto SANTANDER
# creado 1234727 => CONCORDIA en el dpto MAGDALENA
# creado 1234728 => GARZON en el dpto HUILA
# creado 1234729 => BECERRIL en el dpto CESAR
# creado 1234730 => PORE en el dpto CASANARE
# creado 1234731 => GRANADA en el dpto ANTIOQUIA
# creado 1234732 => CHAPARRAL en el dpto TOLIMA
# creado 1234733 => CONVENCION en el dpto NORTE DE SANTANDER
# creado 1234734 => FOMEQUE en el dpto CUNDINAMARCA
# creado 1234735 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1234736 => PUEBLOVIEJO en el dpto MAGDALENA
# creado 1234737 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1234738 => EL BAGRE en el dpto ANTIOQUIA
# creado 1234739 => EL COPEY en el dpto CESAR
# creado 1234740 => AQUITANIA en el dpto BOYACA
# creado 1234741 => ORITO en el dpto PUTUMAYO
# creado 1234742 => CAJIBIO en el dpto CAUCA
# creado 1234743 => URUMITA en el dpto LA GUAJIRA
# creado 1234744 => PLATO en el dpto MAGDALENA
# creado 1234745 => MAJAGUAL en el dpto SUCRE
# creado 1234746 => SANTIAGO DE CALI en el dpto VALLE
# creado 1234747 => LA PAZ en el dpto SANTANDER
# creado 1234748 => CICUCO en el dpto BOLIVAR
# creado 1234749 => SIMACOTA en el dpto SANTANDER
# creado 1234750 => HONDA en el dpto TOLIMA
# creado 1234751 => JAMUNDI en el dpto VALLE
# creado 1234752 => PUERTO ESCONDIDO en el dpto CORDOBA
# creado 1234753 => GIRON en el dpto SANTANDER
# creado 1234754 => BARRANCABERMEJA en el dpto SANTANDER
# creado 1234755 => BELLO en el dpto ANTIOQUIA
# creado 1234756 => BARRANQUILLA en el dpto ATLANTICO
# creado 1234757 => TIBACUY en el dpto CUNDINAMARCA
# creado 1234758 => MARMATO en el dpto CALDAS
# creado 1234759 => TEORAMA en el dpto NORTE DE SANTANDER
# creado 1234760 => SAN JOSE DE URE en el dpto CORDOBA
# creado 1234761 => VALLE DEL GUAMUEZ en el dpto PUTUMAYO
# creado 1234762 => LA VICTORIA en el dpto VALLE
# creado 1234763 => EL COPEY en el dpto CESAR
# creado 1234764 => POPAYAN en el dpto CAUCA
# creado 1234765 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1234766 => PUERTO GUZMAN en el dpto PUTUMAYO
# creado 1234767 => VILLANUEVA en el dpto LA GUAJIRA
# creado 1234768 => PLANADAS en el dpto TOLIMA
# creado 1234769 => SAN ANTERO en el dpto CORDOBA
# creado 1234770 => EL ROSAL en el dpto CUNDINAMARCA
# creado 1234771 => PIENDAMO en el dpto CAUCA
# creado 1234772 => QUIPAMA en el dpto BOYACA
# creado 1234773 => CIMITARRA en el dpto SANTANDER
# creado 1234774 => SAN BERNARDO DEL VIENTO en el dpto CORDOBA
# creado 1234775 => BELALCAZAR en el dpto CALDAS
# creado 1234776 => PASTO en el dpto NARINO
# creado 1234777 => SAN CALIXTO en el dpto NORTE DE SANTANDER
# creado 1234778 => FONSECA en el dpto LA GUAJIRA
# creado 1234779 => SALAZAR en el dpto NORTE DE SANTANDER
# creado 1234780 => SAN MIGUEL DE SEMA en el dpto BOYACA
# creado 1234781 => PASCA en el dpto CUNDINAMARCA
# creado 1234782 => CUMARIBO en el dpto VICHADA
# creado 1234783 => SAN JUANITO en el dpto META
# creado 1234784 => EL PENOL en el dpto NARINO
# creado 1234785 => SANTA ROSA DE VITERBO en el dpto BOYACA
# creado 1234786 => PROVIDENCIA en el dpto SAN ANDRES
# creado 1234787 => SABANA DE TORRES en el dpto SANTANDER
# creado 1234788 => MEDELLIN en el dpto ANTIOQUIA
# creado 1234789 => MAGANGUE en el dpto BOLIVAR
# creado 1234790 => GUALMATAN en el dpto NARINO
# creado 1234791 => VALLEDUPAR en el dpto CESAR
# creado 1234792 => CHIGORODO en el dpto ANTIOQUIA
# creado 1234793 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 1234794 => GUALMATAN en el dpto NARINO
# creado 1234795 => BELEN en el dpto BOYACA
# creado 1234796 => ZARZAL en el dpto VALLE
# creado 1234797 => FLORENCIA en el dpto CAQUETA
# creado 1234798 => VILLA RICA en el dpto CAUCA
# creado 1234799 => SAN MARTIN en el dpto META
# creado 1234800 => PINILLOS en el dpto BOLIVAR
# creado 1234801 => SAN PABLO en el dpto BOLIVAR
# creado 1234802 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 1234803 => CAJAMARCA en el dpto TOLIMA
# creado 1234804 => MAGANGUE en el dpto BOLIVAR
# creado 1234805 => PUEBLORRICO en el dpto ANTIOQUIA
# creado 1234806 => CAUCASIA en el dpto ANTIOQUIA
# creado 1234807 => GUAYABAL en el dpto TOLIMA
# creado 1234808 => LOS PATIOS en el dpto NORTE DE SANTANDER
# creado 1234809 => JAMUNDI en el dpto VALLE
# creado 1234810 => PAIPA en el dpto BOYACA
# creado 1234811 => TURBACO en el dpto BOLIVAR
# creado 1234812 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1234813 => SAN LORENZO en el dpto NARINO
# creado 1234814 => GUARANDA en el dpto SUCRE
# creado 1234815 => PIEDECUESTA en el dpto SANTANDER
# creado 1234816 => CRAVO NORTE en el dpto ARAUCA
# creado 1234817 => SAN BERNARDO DEL VIENTO en el dpto CORDOBA
# creado 1234818 => ITUANGO en el dpto ANTIOQUIA
# creado 1234819 => SAN LUIS en el dpto ANTIOQUIA
# creado 1234820 => JAMBALO en el dpto CAUCA
# creado 1234821 => CHINCHINA en el dpto CALDAS
# creado 1234822 => SIBATE en el dpto CUNDINAMARCA
# creado 1234823 => TUMACO en el dpto NARINO
# creado 1234824 => YOPAL en el dpto CASANARE
# creado 1234825 => SOGAMOSO en el dpto BOYACA
# creado 1234826 => FACATATIVA en el dpto CUNDINAMARCA
# creado 1234827 => BOSCONIA en el dpto CESAR
# creado 1234828 => PUERTO NARE en el dpto ANTIOQUIA
# creado 1234829 => EL DONCELLO en el dpto CAQUETA
# creado 1234830 => RETIRO en el dpto ANTIOQUIA
# creado 1234831 => BUGA en el dpto VALLE
# creado 1234832 => SANTA LUCIA en el dpto ATLANTICO
# creado 1234833 => YOPAL en el dpto CASANARE
# creado 1234834 => TENJO en el dpto CUNDINAMARCA
# creado 1234835 => PLATO en el dpto MAGDALENA
# creado 1234836 => SAN MARCOS en el dpto SUCRE
# creado 1234837 => SANTA ROSA DE OSOS en el dpto ANTIOQUIA
# creado 1234838 => VALLEDUPAR en el dpto CESAR
# creado 1234839 => ORTEGA en el dpto TOLIMA
# creado 1234840 => CARMEN DE APICALA en el dpto TOLIMA
# creado 1234841 => CHIVOR en el dpto BOYACA
# creado 1234842 => MAICAO en el dpto LA GUAJIRA
# creado 1234843 => CORDOBA en el dpto NARINO
# creado 1234844 => GALAPA en el dpto ATLANTICO
# creado 1234845 => MALAGA en el dpto SANTANDER
# creado 1234846 => POPAYAN en el dpto CAUCA
# creado 1234847 => EL ROSAL en el dpto CUNDINAMARCA
# creado 1234848 => SAN JUAN NEPOMUCENO en el dpto BOLIVAR
# creado 1234849 => PITALITO en el dpto HUILA
# creado 1234850 => MARIA LA BAJA en el dpto BOLIVAR
# creado 1234851 => ARGELIA en el dpto CAUCA
# creado 1234852 => GIRON en el dpto SANTANDER
# creado 1234853 => AMAGA en el dpto ANTIOQUIA
# creado 1234854 => PAZ DE RIO en el dpto BOYACA
# creado 1234855 => REMOLINO en el dpto MAGDALENA
# creado 1234856 => ARMENIA en el dpto QUINDIO
# creado 1234857 => BALBOA en el dpto RISARALDA
# creado 1234858 => SOACHA en el dpto CUNDINAMARCA
# creado 1234859 => SAHAGUN en el dpto CORDOBA
# creado 1234860 => TOLUVIEJO en el dpto SUCRE
# creado 1234861 => VILLANUEVA en el dpto LA GUAJIRA
# creado 1234862 => SAN PABLO en el dpto NARINO
# creado 1234863 => PUEBLO NUEVO en el dpto CORDOBA
# creado 1234864 => EL PLAYON en el dpto SANTANDER
# creado 1234865 => LABATECA en el dpto NORTE DE SANTANDER
# creado 1234866 => BARRANQUILLA en el dpto ATLANTICO
# creado 1234867 => CHIVOLO en el dpto MAGDALENA
# creado 1234868 => ALPUJARRA en el dpto TOLIMA
# creado 1234869 => BARANOA en el dpto ATLANTICO
# creado 1234870 => ARMENIA en el dpto QUINDIO
# creado 1234871 => LOPEZ DE MICAY en el dpto CAUCA
# creado 1234872 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1234873 => PUEBLO NUEVO en el dpto CORDOBA
# creado 1234874 => CAIMITO en el dpto SUCRE
# creado 1234875 => EL BANCO en el dpto MAGDALENA
# creado 1234876 => PESCA en el dpto BOYACA
# creado 1234877 => BUENAVENTURA en el dpto VALLE
# creado 1234878 => CALARCA en el dpto QUINDIO
# creado 1234879 => BUCARASICA en el dpto NORTE DE SANTANDER
# creado 1234880 => CAQUEZA en el dpto CUNDINAMARCA
# creado 1234881 => PUERTO CAICEDO en el dpto PUTUMAYO
# creado 1234882 => PASTO en el dpto NARINO
# creado 1234883 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 1234884 => TUMACO en el dpto NARINO
# creado 1234885 => CHIQUINQUIRA en el dpto BOYACA
# creado 1234886 => VALENCIA en el dpto CORDOBA
# creado 1234887 => EL BANCO en el dpto MAGDALENA
# creado 1234888 => ARBELAEZ en el dpto CUNDINAMARCA
# creado 1234889 => PIEDECUESTA en el dpto SANTANDER
# creado 1234890 => CAÑASGORDAS en el dpto ANTIOQUIA
# creado 1234891 => CARCASI en el dpto SANTANDER
# creado 1234892 => SANTA HELENA DEL OPON en el dpto SANTANDER
# creado 1234893 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1234894 => CALDONO en el dpto CAUCA
# creado 1234895 => MARIPI en el dpto BOYACA
# creado 1234896 => VENTAQUEMADA en el dpto BOYACA
# creado 1234897 => NATAGAIMA en el dpto TOLIMA
# creado 1234898 => CUNDAY en el dpto TOLIMA
# creado 1234899 => GUADALUPE en el dpto HUILA
# creado 1234900 => USIACURI en el dpto ATLANTICO
# creado 1234901 => BUENAVENTURA en el dpto VALLE
# creado 1234902 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 1234903 => CHACHAGUI en el dpto NARINO
# creado 1234904 => HATO COROZAL en el dpto CASANARE
# creado 1234905 => SINCELEJO en el dpto SUCRE
# creado 1234906 => SARAVENA en el dpto ARAUCA
# creado 1234907 => CERRO SAN ANTONIO en el dpto MAGDALENA
# creado 1234908 => SAHAGUN en el dpto CORDOBA
# creado 1234909 => JERICO en el dpto ANTIOQUIA
# creado 1234910 => CHIA en el dpto CUNDINAMARCA
# creado 1234911 => SOACHA en el dpto CUNDINAMARCA
# creado 1234912 => PURIFICACION en el dpto TOLIMA
# creado 1234913 => SAMPUES en el dpto SUCRE
# creado 1234914 => ANOLAIMA en el dpto CUNDINAMARCA
# creado 1234915 => ANORI en el dpto ANTIOQUIA
# creado 1234916 => CAIMITO en el dpto SUCRE
# creado 1234917 => SAN PELAYO en el dpto CORDOBA
# creado 1234918 => S.ANTONIO TEQUENDAMA en el dpto CUNDINAMARCA
# creado 1234919 => SOACHA en el dpto CUNDINAMARCA
# creado 1234920 => VILLAVICENCIO en el dpto META
# creado 1234921 => SOACHA en el dpto CUNDINAMARCA
# creado 1234922 => INZA en el dpto CAUCA
# creado 1234923 => SARDINATA en el dpto NORTE DE SANTANDER
# creado 1234924 => TOCA en el dpto BOYACA
# creado 1234925 => PUERTO LOPEZ en el dpto META
# creado 1234926 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 1234927 => LA DORADA en el dpto CALDAS
# creado 1234928 => CAMPOALEGRE en el dpto HUILA
# creado 1234929 => LA PAZ  ROBLES en el dpto CESAR
# creado 1234930 => MAICAO en el dpto LA GUAJIRA
# creado 1234931 => BARRANCABERMEJA en el dpto SANTANDER
# creado 1234932 => SAN PELAYO en el dpto CORDOBA
# creado 1234933 => FACATATIVA en el dpto CUNDINAMARCA
# creado 1234934 => SANTIAGO en el dpto PUTUMAYO
# creado 1234935 => BOSCONIA en el dpto CESAR
# creado 1234936 => CARTAGENA en el dpto BOLIVAR
# creado 1234937 => AGUACHICA en el dpto CESAR
# creado 1234938 => JAMUNDI en el dpto VALLE
# creado 1234939 => FLORENCIA en el dpto CAQUETA
# creado 1234940 => GALERAS en el dpto SUCRE
# creado 1234941 => CHIA en el dpto CUNDINAMARCA
# creado 1234942 => LORICA en el dpto CORDOBA
# creado 1234943 => CIRCASIA en el dpto QUINDIO
# creado 1234944 => SACAMA en el dpto CASANARE
# creado 1234945 => SAN ANDRES en el dpto SANTANDER
# creado 1234946 => RESTREPO en el dpto VALLE
# creado 1234947 => FORTUL en el dpto ARAUCA
# creado 1234948 => GENOVA en el dpto QUINDIO
# creado 1234949 => CAMPOALEGRE en el dpto HUILA
# creado 1234950 => SILVANIA en el dpto CUNDINAMARCA
# creado 1234951 => PAZ DE ARIPORO en el dpto CASANARE
# creado 1234952 => SALAZAR en el dpto NORTE DE SANTANDER
# creado 1234953 => FRANCIS PIZARRO en el dpto NARINO
# creado 1234954 => SAMANIEGO en el dpto NARINO
# creado 1234955 => LA GLORIA en el dpto CESAR
# creado 1234956 => BUCARAMANGA en el dpto SANTANDER
# creado 1234957 => COPACABANA en el dpto ANTIOQUIA
# creado 1234958 => SAN ALBERTO en el dpto CESAR
# creado 1234959 => MALAMBO en el dpto ATLANTICO
# creado 1234960 => PUERTO LOPEZ en el dpto META
# creado 1234961 => TAURAMENA en el dpto CASANARE
# creado 1234962 => VILLA RICA en el dpto CAUCA
# creado 1234963 => TIBU en el dpto NORTE DE SANTANDER
# creado 1234964 => VALLEDUPAR en el dpto CESAR
# creado 1234965 => FOSCA en el dpto CUNDINAMARCA
# creado 1234966 => EL PLAYON en el dpto SANTANDER
# creado 1234967 => COPACABANA en el dpto ANTIOQUIA
# creado 1234968 => PEREIRA en el dpto RISARALDA
# creado 1234969 => SILVANIA en el dpto CUNDINAMARCA
# creado 1234970 => ALBANIA en el dpto LA GUAJIRA
# creado 1234971 => GALERAS en el dpto SUCRE
# creado 1234972 => SAMPUES en el dpto SUCRE
# creado 1234973 => CHIPAQUE en el dpto CUNDINAMARCA
# creado 1234974 => QUEBRADANEGRA en el dpto CUNDINAMARCA
# creado 1234975 => MAHATES en el dpto BOLIVAR
# creado 1234976 => CABUYARO en el dpto META
# creado 1234977 => JAMUNDI en el dpto VALLE
# creado 1234978 => PUERTO TEJADA en el dpto CAUCA
# creado 1234979 => CARTAGENA en el dpto BOLIVAR
# creado 1234980 => SANTO TOMAS en el dpto ATLANTICO
# creado 1234981 => CAUCASIA en el dpto ANTIOQUIA
# creado 1234982 => JENESANO en el dpto BOYACA
# creado 1234983 => MARIQUITA en el dpto TOLIMA
# creado 1234984 => SAN PELAYO en el dpto CORDOBA
# creado 1234985 => PIEDECUESTA en el dpto SANTANDER
# creado 1234986 => LA SIERRA en el dpto CAUCA
# creado 1234987 => BOLIVAR en el dpto ANTIOQUIA
# creado 1234988 => SUAZA en el dpto HUILA
# creado 1234989 => TUCHIN en el dpto CORDOBA
# creado 1234990 => SANTA MARTA en el dpto MAGDALENA
# creado 1234991 => BAJO BAUDO en el dpto CHOCO
# creado 1234992 => NECOCLI en el dpto ANTIOQUIA
# creado 1234993 => CORINTO en el dpto CAUCA
# creado 1234994 => BARRANCO MINAS en el dpto GUAINIA
# creado 1234995 => DISTRACCION en el dpto LA GUAJIRA
# creado 1234996 => SAN JUAN DE ARAMA en el dpto META
# creado 1234997 => GIGANTE en el dpto HUILA
# creado 1234998 => MANZANARES en el dpto CALDAS
# creado 1234999 => MORELIA en el dpto CAQUETA
# creado 1235000 => SOPLAVIENTO en el dpto BOLIVAR
# creado 1235001 => CAICEDONIA en el dpto VALLE
# creado 1235002 => SANTIAGO DE CALI en el dpto VALLE
# creado 1235003 => MONTERIA en el dpto CORDOBA
# creado 1235004 => LEBRIJA en el dpto SANTANDER
# creado 1235005 => SAN FRANCISCO en el dpto ANTIOQUIA
# creado 1235006 => ZAMBRANO en el dpto BOLIVAR
# creado 1235007 => SAN ANTERO en el dpto CORDOBA
# creado 1235008 => PUEBLO BELLO en el dpto CESAR
# creado 1235009 => EL PLAYON en el dpto SANTANDER
# creado 1235010 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 1235011 => MALAGA en el dpto SANTANDER
# creado 1235012 => CAPARRAPI en el dpto CUNDINAMARCA
# creado 1235013 => ACACIAS en el dpto META
# creado 1235014 => ZIPACON en el dpto CUNDINAMARCA
# creado 1235015 => CHIRIGUANA en el dpto CESAR
# creado 1235016 => REMEDIOS en el dpto ANTIOQUIA
# creado 1235017 => CICUCO en el dpto BOLIVAR
# creado 1235018 => CABUYARO en el dpto META
# creado 1235019 => MALAMBO en el dpto ATLANTICO
# creado 1235020 => MORALES en el dpto CAUCA
# creado 1235021 => RIOHACHA en el dpto LA GUAJIRA
# creado 1235022 => TAMALAMEQUE en el dpto CESAR
# creado 1235023 => GONZALEZ en el dpto CESAR
# creado 1235024 => QUIBDO en el dpto CHOCO
# creado 1235025 => TURBO en el dpto ANTIOQUIA
# creado 1235026 => HERVEO en el dpto TOLIMA
# creado 1235027 => CAJIBIO en el dpto CAUCA
# creado 1235028 => BUCARAMANGA en el dpto SANTANDER
# creado 1235029 => MISTRATO en el dpto RISARALDA
# creado 1235030 => PEREIRA en el dpto RISARALDA
# creado 1235031 => SASAIMA en el dpto CUNDINAMARCA
# creado 1235032 => CODAZZI en el dpto CESAR
# creado 1235033 => ZARZAL en el dpto VALLE
# creado 1235034 => NEIVA en el dpto HUILA
# creado 1235035 => SUAREZ en el dpto TOLIMA
# creado 1235036 => BETULIA en el dpto SANTANDER
# creado 1235037 => CUASPUD en el dpto NARINO
# creado 1235038 => MOCOA en el dpto PUTUMAYO
# creado 1235039 => RONCESVALLES en el dpto TOLIMA
# creado 1235040 => MEDELLIN en el dpto ANTIOQUIA
# creado 1235041 => MANZANARES en el dpto CALDAS
# creado 1235042 => POLICARPA en el dpto NARINO
# creado 1235043 => TARQUI en el dpto HUILA
# creado 1235044 => SAN ONOFRE en el dpto SUCRE
# creado 1235045 => CARTAGENA en el dpto BOLIVAR
# creado 1235046 => GUAMO en el dpto TOLIMA
# creado 1235047 => TERUEL en el dpto HUILA
# creado 1235048 => YALI en el dpto ANTIOQUIA
# creado 1235049 => BOCHALEMA en el dpto NORTE DE SANTANDER
# creado 1235050 => CARMEN DE APICALA en el dpto TOLIMA
# creado 1235051 => MOCOA en el dpto PUTUMAYO
# creado 1235052 => MANAURE en el dpto LA GUAJIRA
# creado 1235053 => SORA en el dpto BOYACA
# creado 1235054 => NEIVA en el dpto HUILA
# creado 1235055 => SALAMINA en el dpto CALDAS
# creado 1235056 => CANDELARIA en el dpto VALLE
# creado 1235057 => MEDELLIN en el dpto ANTIOQUIA
# creado 1235058 => FIRAVITOBA en el dpto BOYACA
# creado 1235059 => PORE en el dpto CASANARE
# creado 1235060 => TORIBIO en el dpto CAUCA
# creado 1235061 => SUPATA en el dpto CUNDINAMARCA
# creado 1235062 => FUNDACION en el dpto MAGDALENA
# creado 1235063 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1235064 => PATIA (EL BORDO) en el dpto CAUCA
# creado 1235065 => SIACHOQUE en el dpto BOYACA
# creado 1235066 => CONCORDIA en el dpto ANTIOQUIA
# creado 1235067 => CARTAGO en el dpto VALLE
# creado 1235068 => SABANALARGA en el dpto ATLANTICO
# creado 1235069 => IBAGUE en el dpto TOLIMA
# creado 1235070 => BARRANQUILLA en el dpto ATLANTICO
# creado 1235071 => USIACURI en el dpto ATLANTICO
# creado 1235072 => PUERTO ASIS en el dpto PUTUMAYO
# creado 1235073 => VILLA DEL ROSARIO en el dpto NORTE DE SANTANDER
# creado 1235074 => TOLU en el dpto SUCRE
# creado 1235075 => SOACHA en el dpto CUNDINAMARCA
# creado 1235076 => PASTO en el dpto NARINO
# creado 1235077 => CORINTO en el dpto CAUCA
# creado 1235078 => BARRANCABERMEJA en el dpto SANTANDER
# creado 1235079 => RIOHACHA en el dpto LA GUAJIRA
# creado 1235080 => ALBANIA en el dpto LA GUAJIRA
# creado 1235081 => SAN LORENZO en el dpto NARINO
# creado 1235082 => PADILLA en el dpto CAUCA
# creado 1235083 => QUINCHIA en el dpto RISARALDA
# creado 1235084 => LA TEBAIDA en el dpto QUINDIO
# creado 1235085 => BELEN DE LOS ANDAQUIES en el dpto CAQUETA
# creado 1235086 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 1235087 => SANTA ANA en el dpto MAGDALENA
# creado 1235088 => CHIPATA en el dpto SANTANDER
# creado 1235089 => TAME en el dpto ARAUCA
# creado 1235090 => TASCO en el dpto BOYACA
# creado 1235091 => MAGANGUE en el dpto BOLIVAR
# creado 1235092 => ALBAN en el dpto NARINO
# creado 1235093 => MALAGA en el dpto SANTANDER
# creado 1235094 => PADILLA en el dpto CAUCA
# creado 1235095 => FUNZA en el dpto CUNDINAMARCA
# creado 1235096 => RIO QUITO en el dpto CHOCO
# creado 1235097 => ATACO en el dpto TOLIMA
# creado 1235098 => TORO en el dpto VALLE
# creado 1235099 => FLORENCIA en el dpto CAQUETA
# creado 1235100 => ALBANIA en el dpto LA GUAJIRA
# creado 1235101 => DIBULLA en el dpto LA GUAJIRA
# creado 1235102 => GUATAPE en el dpto ANTIOQUIA
# creado 1235103 => CAIMITO en el dpto SUCRE
# creado 1235104 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1235105 => FLORIDABLANCA en el dpto SANTANDER
# creado 1235106 => QUIMBAYA en el dpto QUINDIO
# creado 1235107 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1235108 => VILLETA en el dpto CUNDINAMARCA
# creado 1235109 => TUQUERRES en el dpto NARINO
# creado 1235110 => CONTRATACION en el dpto SANTANDER
# creado 1235111 => ACACIAS en el dpto META
# creado 1235112 => SANTO TOMAS en el dpto ATLANTICO
# creado 1235113 => FLORIDABLANCA en el dpto SANTANDER
# creado 1235114 => CHIMICHAGUA en el dpto CESAR
# creado 1235115 => LA ESTRELLA en el dpto ANTIOQUIA
# creado 1235116 => PRADO en el dpto TOLIMA
# creado 1235117 => SUTATENZA en el dpto BOYACA
# creado 1235118 => MARIA LA BAJA en el dpto BOLIVAR
# creado 1235119 => PUERTO SANTANDER en el dpto NORTE DE SANTANDER
# creado 1235120 => SATIVASUR en el dpto BOYACA
# creado 1235121 => COYAIMA en el dpto TOLIMA
# creado 1235122 => LA UNION en el dpto ANTIOQUIA
# creado 1235123 => CAICEDONIA en el dpto VALLE
# creado 1235124 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1235125 => BUENOS AIRES en el dpto CAUCA
# creado 1235126 => LA UNION en el dpto SUCRE
# creado 1235127 => PUERTO ESCONDIDO en el dpto CORDOBA
# creado 1235128 => SANTA MARTA en el dpto MAGDALENA
# creado 1235129 => MEDELLIN en el dpto ANTIOQUIA
# creado 1235130 => ANOLAIMA en el dpto CUNDINAMARCA
# creado 1235131 => SANTIAGO DE CALI en el dpto VALLE
# creado 1235132 => BITUIMA en el dpto CUNDINAMARCA
# creado 1235133 => CHACHAGUI en el dpto NARINO
# creado 1235134 => PAIPA en el dpto BOYACA
# creado 1235135 => BUCARAMANGA en el dpto SANTANDER
# creado 1235136 => UNGUIA en el dpto CHOCO
# creado 1235137 => CARTAGENA en el dpto BOLIVAR
# creado 1235138 => GUAPI en el dpto CAUCA
# creado 1235139 => PLANETA RICA en el dpto CORDOBA
# creado 1235140 => TIQUISIO en el dpto BOLIVAR
# creado 1235141 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 1235142 => MONTERREY en el dpto CASANARE
# creado 1235143 => BUENAVENTURA en el dpto VALLE
# creado 1235144 => ITSMINA en el dpto CHOCO
# creado 1235145 => MADRID en el dpto CUNDINAMARCA
# creado 1235146 => CAICEDONIA en el dpto VALLE
# creado 1235147 => TUCHIN en el dpto CORDOBA
# creado 1235148 => GALAPA en el dpto ATLANTICO
# creado 1235149 => SARAVENA en el dpto ARAUCA
# creado 1235150 => MONTECRISTO en el dpto BOLIVAR
# creado 1235151 => CHINU en el dpto CORDOBA
# creado 1235152 => PUERTO ASIS en el dpto PUTUMAYO
# creado 1235153 => PURIFICACION en el dpto TOLIMA
# creado 1235154 => SAN GIL en el dpto SANTANDER
# creado 1235155 => CHAPARRAL en el dpto TOLIMA
# creado 1235156 => PEREIRA en el dpto RISARALDA
# creado 1235157 => JAMUNDI en el dpto VALLE
# creado 1235158 => SAMANIEGO en el dpto NARINO
# creado 1235159 => SAN BERNARDO DEL VIENTO en el dpto CORDOBA
# creado 1235160 => SASAIMA en el dpto CUNDINAMARCA
# creado 1235161 => CARTAGENA en el dpto BOLIVAR
# creado 1235162 => LA VICTORIA en el dpto VALLE
# creado 1235163 => CALIMA en el dpto VALLE
# creado 1235164 => AGUACHICA en el dpto CESAR
# creado 1235165 => SANTIAGO DE CALI en el dpto VALLE
# creado 1235166 => ACEVEDO en el dpto HUILA
# creado 1235167 => RONCESVALLES en el dpto TOLIMA
# creado 1235168 => ALBANIA en el dpto LA GUAJIRA
# creado 1235169 => TIBU en el dpto NORTE DE SANTANDER
# creado 1235170 => MANIZALES en el dpto CALDAS
# creado 1235171 => SABANALARGA en el dpto ATLANTICO
# creado 1235172 => ANGOSTURA en el dpto ANTIOQUIA
# creado 1235173 => LOS ANDES en el dpto NARINO
# creado 1235174 => YONDO en el dpto ANTIOQUIA
# creado 1235175 => SOLEDAD en el dpto ATLANTICO
# creado 1235176 => SAN ANTONIO en el dpto TOLIMA
# creado 1235177 => GRAMALOTE en el dpto NORTE DE SANTANDER
# creado 1235178 => LABRANZAGRANDE en el dpto BOYACA
# creado 1235179 => OVEJAS en el dpto SUCRE
# creado 1235180 => SIMIJACA en el dpto CUNDINAMARCA
# creado 1235181 => PARAMO en el dpto SANTANDER
# creado 1235182 => CARTAGENA en el dpto BOLIVAR
# creado 1235183 => SANTA MARTA en el dpto MAGDALENA
# creado 1235184 => BARRANQUILLA en el dpto ATLANTICO
# creado 1235185 => BELEN DE UMBRIA en el dpto RISARALDA
# creado 1235186 => SAN BENITO ABAD en el dpto SUCRE
# creado 1235187 => VILLANUEVA en el dpto SANTANDER
# creado 1235188 => HISPANIA en el dpto ANTIOQUIA
# creado 1235189 => SINCELEJO en el dpto SUCRE
# creado 1235190 => BUENAVENTURA en el dpto VALLE
# creado 1235191 => LORICA en el dpto CORDOBA
# creado 1235192 => SAN BENITO ABAD en el dpto SUCRE
# creado 1235193 => PUEBLO NUEVO en el dpto CORDOBA
# creado 1235194 => PUEBLO RICO en el dpto RISARALDA
# creado 1235195 => APARTADO en el dpto ANTIOQUIA
# creado 1235196 => BUCARAMANGA en el dpto SANTANDER
# creado 1235197 => UNGUIA en el dpto CHOCO
# creado 1235198 => YUMBO en el dpto VALLE
# creado 1235199 => SANTIAGO DE CALI en el dpto VALLE
# creado 1235200 => PEREIRA en el dpto RISARALDA
# creado 1235201 => LA ESTRELLA en el dpto ANTIOQUIA
# creado 1235202 => CAMPO DE LA CRUZ en el dpto ATLANTICO
# creado 1235203 => BUENAVENTURA en el dpto VALLE
# creado 1235204 => BARANOA en el dpto ATLANTICO
# creado 1235205 => BARBOSA en el dpto ANTIOQUIA
# creado 1235206 => SUAREZ en el dpto CAUCA
# creado 1235207 => EL BANCO en el dpto MAGDALENA
# creado 1235208 => VALLEDUPAR en el dpto CESAR
# creado 1235209 => MANIZALES en el dpto CALDAS
# creado 1235210 => FRESNO en el dpto TOLIMA
# creado 1235211 => SOPLAVIENTO en el dpto BOLIVAR
# creado 1235212 => VENTAQUEMADA en el dpto BOYACA
# creado 1235213 => IPIALES en el dpto NARINO
# creado 1235214 => ANSERMA en el dpto CALDAS
# creado 1235215 => COPACABANA en el dpto ANTIOQUIA
# creado 1235216 => BAHIA SOLANO en el dpto CHOCO
# creado 1235217 => SAN AGUSTIN en el dpto HUILA
# creado 1235218 => EL TAMBO en el dpto NARINO
# creado 1235219 => MESETAS en el dpto META
# creado 1235220 => PACHAVITA en el dpto BOYACA
# creado 1235221 => CHIRIGUANA en el dpto CESAR
# creado 1235222 => CARTAGENA en el dpto BOLIVAR
# creado 1235223 => CHINU en el dpto CORDOBA
# creado 1235224 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 1235225 => TAURAMENA en el dpto CASANARE
# creado 1235226 => SAN ALBERTO en el dpto CESAR
# creado 1235227 => SAN JOSE DE FRAGUA en el dpto CAQUETA
# creado 1235228 => BARRANQUILLA en el dpto ATLANTICO
# creado 1235229 => CAJAMARCA en el dpto TOLIMA
# creado 1235230 => PIJAO en el dpto QUINDIO
# creado 1235231 => TURBO en el dpto ANTIOQUIA
# creado 1235232 => MARINILLA en el dpto ANTIOQUIA
# creado 1235233 => TULUA en el dpto VALLE
# creado 1235234 => TRINIDAD en el dpto CASANARE
# creado 1235235 => SAHAGUN en el dpto CORDOBA
# creado 1235236 => APIA en el dpto RISARALDA
# creado 1235237 => CARMEN DE CARUPA en el dpto CUNDINAMARCA
# creado 1235238 => LA MERCED en el dpto CALDAS
# creado 1235239 => NUEVO COLON en el dpto BOYACA
# creado 1235240 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1235241 => OBANDO en el dpto VALLE
# creado 1235242 => BUGALAGRANDE en el dpto VALLE
# creado 1235243 => CAJIBIO en el dpto CAUCA
# creado 1235244 => PEÑOL en el dpto ANTIOQUIA
# creado 1235245 => CARTAGENA en el dpto BOLIVAR
# creado 1235246 => SAN ANDRES en el dpto SANTANDER
# creado 1235247 => NILO en el dpto CUNDINAMARCA
# creado 1235248 => SAN PEDRO en el dpto SUCRE
# creado 1235249 => TOGUI en el dpto BOYACA
# creado 1235250 => VILLAVIEJA en el dpto HUILA
# creado 1235251 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 1235252 => LLORO en el dpto CHOCO
# creado 1235253 => AGUACHICA en el dpto CESAR
# creado 1235254 => GIRALDO en el dpto ANTIOQUIA
# creado 1235255 => CHINCHINA en el dpto CALDAS
# creado 1235256 => LA DORADA en el dpto CALDAS
# creado 1235257 => MOMIL en el dpto CORDOBA
# creado 1235258 => BOSCONIA en el dpto CESAR
# creado 1235259 => EL ROBLE en el dpto SUCRE
# creado 1235260 => URIBIA en el dpto LA GUAJIRA
# creado 1235261 => MONGUA en el dpto BOYACA
# creado 1235262 => PUERTO GAITAN en el dpto META
# creado 1235263 => FUQUENE en el dpto CUNDINAMARCA
# creado 1235264 => TESALIA en el dpto HUILA
# creado 1235265 => ISNOS en el dpto HUILA
# creado 1235266 => MARSELLA en el dpto RISARALDA
# creado 1235267 => CUBARRAL en el dpto META
# creado 1235268 => CUMARAL en el dpto META
# creado 1235269 => VILLANUEVA en el dpto LA GUAJIRA
# creado 1235270 => ARENAL en el dpto BOLIVAR
# creado 1235271 => LA DORADA en el dpto CALDAS
# creado 1235272 => MEDELLIN en el dpto ANTIOQUIA
# creado 1235273 => JAMUNDI en el dpto VALLE
# creado 1235274 => CACHIPAY en el dpto CUNDINAMARCA
# creado 1235275 => SAN JUAN DE ARAMA en el dpto META
# creado 1235276 => SANTA MARIA en el dpto HUILA
# creado 1235277 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1235278 => SOPO en el dpto CUNDINAMARCA
# creado 1235279 => BUGA en el dpto VALLE
# creado 1235280 => TOCAIMA en el dpto CUNDINAMARCA
# creado 1235281 => IBAGUE en el dpto TOLIMA
# creado 1235282 => LA CEJA en el dpto ANTIOQUIA
# creado 1235283 => EL TABLON en el dpto NARINO
# creado 1235284 => TAURAMENA en el dpto CASANARE
# creado 1235285 => PINILLOS en el dpto BOLIVAR
# creado 1235286 => EL CAIRO en el dpto VALLE
# creado 1235287 => SAN FRANCISCO en el dpto CUNDINAMARCA
# creado 1235288 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1235289 => LA PAZ  ROBLES en el dpto CESAR
# creado 1235290 => SALADOBLANCO en el dpto HUILA
# creado 1235291 => LA PLATA en el dpto HUILA
# creado 1235292 => LA UNION en el dpto NARINO
# creado 1235293 => OIBA en el dpto SANTANDER
# creado 1235294 => CHIVOLO en el dpto MAGDALENA
# creado 1235295 => SOCOTA en el dpto BOYACA
# creado 1235296 => TUCHIN en el dpto CORDOBA
# creado 1235297 => SAN PABLO DE BORBUR en el dpto BOYACA
# creado 1235298 => MONTERIA en el dpto CORDOBA
# creado 1235299 => COLON en el dpto PUTUMAYO
# creado 1235300 => SAN SEBASTIAN BUENAVIST en el dpto MAGDALENA
# creado 1235301 => ALGARROBO en el dpto MAGDALENA
# creado 1235302 => SANTO TOMAS en el dpto ATLANTICO
# creado 1235303 => SANTIAGO en el dpto PUTUMAYO
# creado 1235304 => RIVERA en el dpto HUILA
# creado 1235305 => TOTA en el dpto BOYACA
# creado 1235306 => MAICAO en el dpto LA GUAJIRA
# creado 1235307 => EL PEÑON en el dpto BOLIVAR
# creado 1235308 => JAMUNDI en el dpto VALLE
# creado 1235309 => MARINILLA en el dpto ANTIOQUIA
# creado 1235310 => OICATA en el dpto BOYACA
# creado 1235311 => UNGUIA en el dpto CHOCO
# creado 1235312 => TORO en el dpto VALLE
# creado 1235313 => VILLANUEVA en el dpto LA GUAJIRA
# creado 1235314 => SANTO TOMAS en el dpto ATLANTICO
# creado 1235315 => URIBIA en el dpto LA GUAJIRA
# ...
# creado 1239003 => PRADERA en el dpto VALLE
# creado 1239004 => GIRARDOT en el dpto CUNDINAMARCA
# creado 1239005 => VALLEDUPAR en el dpto CESAR
# creado 1239006 => SAN ONOFRE en el dpto SUCRE
# creado 1239007 => PUEBLO NUEVO en el dpto CORDOBA
# creado 1239008 => VILLA DEL ROSARIO en el dpto NORTE DE SANTANDER
# creado 1239009 => CHIRIGUANA en el dpto CESAR
# creado 1239010 => NEMOCON en el dpto CUNDINAMARCA
# creado 1239011 => ASTREA en el dpto CESAR
# creado 1239012 => AQUITANIA en el dpto BOYACA
# creado 1239013 => GENOVA en el dpto QUINDIO
# creado 1239014 => TUNUNGUA en el dpto BOYACA
# creado 1239015 => MONTERIA en el dpto CORDOBA
# creado 1239016 => OLAYA en el dpto ANTIOQUIA
# creado 1239017 => SAN ONOFRE en el dpto SUCRE
# creado 1239018 => MANIZALES en el dpto CALDAS
# creado 1239019 => SAN CALIXTO en el dpto NORTE DE SANTANDER
# creado 1239020 => TENERIFE en el dpto MAGDALENA
# creado 1239021 => MACANAL en el dpto BOYACA
# creado 1239022 => LOS CORDOBAS en el dpto CORDOBA
# creado 1239023 => ZAMBRANO en el dpto BOLIVAR
# creado 1239024 => CHIGORODO en el dpto ANTIOQUIA
# creado 1239025 => SOCORRO en el dpto SANTANDER
# creado 1239026 => EL CHARCO en el dpto NARINO
# creado 1239027 => SINCELEJO en el dpto SUCRE
# creado 1239028 => CHITAGA en el dpto NORTE DE SANTANDER
# creado 1239029 => MAICAO en el dpto LA GUAJIRA
# creado 1239030 => SANTA MARTA en el dpto MAGDALENA
# creado 1239031 => SOACHA en el dpto CUNDINAMARCA
# creado 1239032 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 1239033 => COTA en el dpto CUNDINAMARCA
# creado 1239034 => MARSELLA en el dpto RISARALDA
# creado 1239035 => TURMEQUE en el dpto BOYACA
# creado 1239036 => CAMPAMENTO en el dpto ANTIOQUIA
# creado 1239037 => OLAYA en el dpto ANTIOQUIA
# creado 1239038 => MARIA LA BAJA en el dpto BOLIVAR
# creado 1239039 => GIRON en el dpto SANTANDER
# creado 1239040 => SANTUARIO en el dpto RISARALDA
# creado 1239041 => ALGECIRAS en el dpto HUILA
# creado 1239042 => QUIMBAYA en el dpto QUINDIO
# creado 1239043 => MISTRATO en el dpto RISARALDA
# creado 1239044 => BUGA en el dpto VALLE
# creado 1239045 => EL CARMEN en el dpto SANTANDER
# creado 1239046 => PUERTO  LEGUIZAMO en el dpto PUTUMAYO
# creado 1239047 => JURADO en el dpto CHOCO
# creado 1239048 => CAMPAMENTO en el dpto ANTIOQUIA
# creado 1239049 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 1239050 => SAN MIGUEL en el dpto PUTUMAYO
# creado 1239051 => BELMIRA en el dpto ANTIOQUIA
# creado 1239052 => MANAURE en el dpto LA GUAJIRA
# creado 1239053 => PALMIRA en el dpto VALLE
# creado 1239054 => PEQUE en el dpto ANTIOQUIA
# creado 1239055 => SANDONA en el dpto NARINO
# creado 1239056 => SANTIAGO DE CALI en el dpto VALLE
# creado 1239057 => YOTOCO en el dpto VALLE
# creado 1239058 => BARBOSA en el dpto ANTIOQUIA
# creado 1239059 => UNION PANAMERICANA en el dpto CHOCO
# creado 1239060 => URAMITA en el dpto ANTIOQUIA
# creado 1239061 => YOPAL en el dpto CASANARE
# creado 1239062 => COVEÑAS en el dpto SUCRE
# creado 1239063 => ANAPOIMA en el dpto CUNDINAMARCA
# creado 1239064 => CHOCONTA en el dpto CUNDINAMARCA
# creado 1239065 => TIQUISIO en el dpto BOLIVAR
# creado 1239066 => PAZ DE ARIPORO en el dpto CASANARE
# creado 1239067 => SAN VICENTE DEL CAGUAN en el dpto CAQUETA
# creado 1239068 => SOTARA en el dpto CAUCA
# creado 1239069 => SAN PELAYO en el dpto CORDOBA
# creado 1239070 => TAME en el dpto ARAUCA
# creado 1239071 => FONSECA en el dpto LA GUAJIRA
# creado 1239072 => ALBANIA en el dpto LA GUAJIRA
# creado 1239073 => AYAPEL en el dpto CORDOBA
# creado 1239074 => FREDONIA en el dpto ANTIOQUIA
# creado 1239075 => RIONEGRO en el dpto SANTANDER
# creado 1239076 => TESALIA en el dpto HUILA
# creado 1239077 => SANTIAGO DE CALI en el dpto VALLE
# creado 1239078 => REPELON en el dpto ATLANTICO
# creado 1239079 => DABEIBA en el dpto ANTIOQUIA
# creado 1239080 => UBATE en el dpto CUNDINAMARCA
# creado 1239081 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 1239082 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1239083 => LA DORADA en el dpto CALDAS
# creado 1239084 => MONIQUIRA en el dpto BOYACA
# creado 1239085 => CHIA en el dpto CUNDINAMARCA
# creado 1239086 => PENSILVANIA en el dpto CALDAS
# creado 1239087 => MORALES en el dpto CAUCA
# creado 1239088 => LA PINTADA en el dpto ANTIOQUIA
# creado 1239089 => SOACHA en el dpto CUNDINAMARCA
# creado 1239090 => ANAPOIMA en el dpto CUNDINAMARCA
# creado 1239091 => FILADELFIA en el dpto CALDAS
# creado 1239092 => SOCORRO en el dpto SANTANDER
# creado 1239093 => MOMPOS en el dpto BOLIVAR
# creado 1239094 => TUMACO en el dpto NARINO
# creado 1239095 => BELALCAZAR en el dpto CALDAS
# creado 1239096 => BARANOA en el dpto ATLANTICO
# creado 1239097 => CUMARIBO en el dpto VICHADA
# creado 1239098 => YARUMAL en el dpto ANTIOQUIA
# creado 1239099 => SAN CARLOS GUAROA en el dpto META
# creado 1239100 => PUERTO LOPEZ en el dpto META
# creado 1239101 => SAN FRANCISCO en el dpto ANTIOQUIA
# creado 1239102 => CICUCO en el dpto BOLIVAR
# creado 1239103 => EL CHARCO en el dpto NARINO
# creado 1239104 => LETICIA en el dpto AMAZONAS
# creado 1239105 => DAGUA en el dpto VALLE
# creado 1239106 => VALLE DEL GUAMUEZ en el dpto PUTUMAYO
# creado 1239107 => FACATATIVA en el dpto CUNDINAMARCA
# creado 1239108 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1239109 => SABANA DE TORRES en el dpto SANTANDER
# creado 1239110 => CALARCA en el dpto QUINDIO
# creado 1239111 => SAN MATEO en el dpto BOYACA
# creado 1239112 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 1239113 => GALAN en el dpto SANTANDER
# creado 1239114 => GUATAQUI en el dpto CUNDINAMARCA
# creado 1239115 => MONTERIA en el dpto CORDOBA
# creado 1239116 => RISARALDA en el dpto CALDAS
# creado 1239117 => ZAMBRANO en el dpto BOLIVAR
# creado 1239118 => MANZANARES en el dpto CALDAS
# creado 1239119 => APARTADO en el dpto ANTIOQUIA
# creado 1239120 => BARRANQUILLA en el dpto ATLANTICO
# creado 1239121 => VILLAGARZON en el dpto PUTUMAYO
# creado 1239122 => RIOHACHA en el dpto LA GUAJIRA
# creado 1239123 => SAN ALBERTO en el dpto CESAR
# creado 1239124 => AGUAZUL en el dpto CASANARE
# creado 1239125 => SOCHA en el dpto BOYACA
# creado 1239126 => PEREIRA en el dpto RISARALDA
# creado 1239127 => SAN PEDRO en el dpto ANTIOQUIA
# creado 1239128 => MANAURE en el dpto LA GUAJIRA
# creado 1239129 => SOACHA en el dpto CUNDINAMARCA
# creado 1239130 => SANTUARIO en el dpto ANTIOQUIA
# creado 1239131 => ABEJORRAL en el dpto ANTIOQUIA
# creado 1239132 => PUERTO BERRIO en el dpto ANTIOQUIA
# creado 1239133 => PINCHOTE en el dpto SANTANDER
# creado 1239134 => LA GLORIA en el dpto CESAR
# creado 1239135 => ARAUCA en el dpto ARAUCA
# creado 1239136 => LA APARTADA en el dpto CORDOBA
# creado 1239137 => TURBACO en el dpto BOLIVAR
# creado 1239138 => LIBANO en el dpto TOLIMA
# creado 1239139 => EL PASO en el dpto CESAR
# creado 1239140 => RIVERA en el dpto HUILA
# creado 1239141 => CODAZZI en el dpto CESAR
# creado 1239142 => SAN MARCOS en el dpto SUCRE
# creado 1239143 => SAN JOSE DEL GUAVIARE en el dpto GUAVIARE
# creado 1239144 => TOGUI en el dpto BOYACA
# creado 1239145 => MELGAR en el dpto TOLIMA
# creado 1239146 => ASTREA en el dpto CESAR
# creado 1239147 => MELGAR en el dpto TOLIMA
# creado 1239148 => VILLETA en el dpto CUNDINAMARCA
# creado 1239149 => CHIGORODO en el dpto ANTIOQUIA
# creado 1239150 => CRAVO NORTE en el dpto ARAUCA
# creado 1239151 => APARTADO en el dpto ANTIOQUIA
# creado 1239152 => PUENTE NACIONAL en el dpto SANTANDER
# creado 1239153 => SIMIJACA en el dpto CUNDINAMARCA
# creado 1239154 => CORDOBA en el dpto NARINO
# creado 1239155 => BARRANCAS en el dpto LA GUAJIRA
# creado 1239156 => MANAURE BALCON DEL CESAR en el dpto CESAR
# creado 1239157 => SAN FERNANDO en el dpto BOLIVAR
# creado 1239158 => CUCAITA en el dpto BOYACA
# creado 1239159 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1239160 => RIOBLANCO en el dpto TOLIMA
# creado 1239161 => GUACHENE en el dpto CAUCA
# creado 1239162 => SANTA ROSA DE VITERBO en el dpto BOYACA
# creado 1239163 => MAJAGUAL en el dpto SUCRE
# creado 1239164 => AMALFI en el dpto ANTIOQUIA
# creado 1239165 => TIMANA en el dpto HUILA
# creado 1239166 => MEDELLIN en el dpto ANTIOQUIA
# creado 1239167 => VILLAVICENCIO en el dpto META
# creado 1239168 => CACHIRA en el dpto NORTE DE SANTANDER
# creado 1239169 => LA URIBE en el dpto META
# creado 1239170 => BALBOA en el dpto CAUCA
# creado 1239171 => APARTADO en el dpto ANTIOQUIA
# creado 1239172 => ACACIAS en el dpto META
# creado 1239173 => PUERTO GAITAN en el dpto META
# creado 1239174 => COVEÑAS en el dpto SUCRE
# creado 1239175 => SAN MIGUEL DE SEMA en el dpto BOYACA
# creado 1239176 => COVARACHIA en el dpto BOYACA
# creado 1239177 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 1239178 => SANTA MARTA en el dpto MAGDALENA
# creado 1239179 => NEIVA en el dpto HUILA
# creado 1239180 => MANAURE en el dpto LA GUAJIRA
# creado 1239181 => MARIPI en el dpto BOYACA
# creado 1239182 => FUNZA en el dpto CUNDINAMARCA
# creado 1239183 => CHOCONTA en el dpto CUNDINAMARCA
# creado 1239184 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 1239185 => MARQUETALIA en el dpto CALDAS
# creado 1239186 => GIRARDOTA en el dpto ANTIOQUIA
# creado 1239187 => BELTRAN en el dpto CUNDINAMARCA
# creado 1239188 => TIERRALTA en el dpto CORDOBA
# creado 1239189 => GUADALUPE en el dpto ANTIOQUIA
# creado 1239190 => SAN VICENTE en el dpto ANTIOQUIA
# creado 1239191 => SINCELEJO en el dpto SUCRE
# creado 1239192 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 1239193 => SAN VICENTE DE CHUCURI en el dpto SANTANDER
# creado 1239194 => MANAURE en el dpto LA GUAJIRA
# creado 1239195 => ARAUCA en el dpto ARAUCA
# creado 1239196 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 1239197 => VITERBO en el dpto CALDAS
# creado 1239198 => PUERTO TEJADA en el dpto CAUCA
# creado 1239199 => DAGUA en el dpto VALLE
# creado 1239200 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 1239201 => PELAYA en el dpto CESAR
# creado 1239202 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 1239203 => SANTA CATALINA en el dpto BOLIVAR
# creado 1239204 => CIRCASIA en el dpto QUINDIO
# creado 1239205 => PRADERA en el dpto VALLE
# creado 1239206 => MONITOS en el dpto CORDOBA
# creado 1239207 => COVEÑAS en el dpto SUCRE
# creado 1239208 => ROBERTO PAYAN en el dpto NARINO
# creado 1239209 => ARANZAZU en el dpto CALDAS
# creado 1239210 => SIMITI en el dpto BOLIVAR
# creado 1239211 => PORE en el dpto CASANARE
# creado 1239212 => CHIVOLO en el dpto MAGDALENA
# creado 1239213 => CHIPATA en el dpto SANTANDER
# creado 1239214 => SANTA ROSA DE VITERBO en el dpto BOYACA
# creado 1239215 => BUENOS AIRES en el dpto CAUCA
# creado 1239216 => PUPIALES en el dpto NARINO
# creado 1239217 => CHISCAS en el dpto BOYACA
# creado 1239218 => BETULIA en el dpto SANTANDER
# creado 1239219 => CORINTO en el dpto CAUCA
# creado 1239220 => BUENAVENTURA en el dpto VALLE
# creado 1239221 => MAICAO en el dpto LA GUAJIRA
# creado 1239222 => PENSILVANIA en el dpto CALDAS
# creado 1239223 => PALMIRA en el dpto VALLE
# creado 1239224 => SAN VICENTE DEL CAGUAN en el dpto CAQUETA
# creado 1239225 => CARTAGO en el dpto VALLE
# creado 1239226 => MARSELLA en el dpto RISARALDA
# creado 1239227 => SARAVENA en el dpto ARAUCA
# creado 1239228 => FLORIDA en el dpto VALLE
# creado 1239229 => CHIA en el dpto CUNDINAMARCA
# creado 1239230 => SAN ANDRES en el dpto SAN ANDRES
# creado 1239231 => SORA en el dpto BOYACA
# creado 1239232 => SAN JUAN NEPOMUCENO en el dpto BOLIVAR
# creado 1239233 => DISTRACCION en el dpto LA GUAJIRA
# creado 1239234 => RIVERA en el dpto HUILA
# creado 1239235 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1239236 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 1239237 => CAJAMARCA en el dpto TOLIMA
# creado 1239238 => CIENAGA en el dpto MAGDALENA
# creado 1239239 => SILVIA en el dpto CAUCA
# creado 1239240 => PEREIRA en el dpto RISARALDA
# creado 1239241 => VALLEDUPAR en el dpto CESAR
# creado 1239242 => URUMITA en el dpto LA GUAJIRA
# creado 1239243 => SIACHOQUE en el dpto BOYACA
# creado 1239244 => SOACHA en el dpto CUNDINAMARCA
# creado 1239245 => ATACO en el dpto TOLIMA
# creado 1239246 => NOVITA en el dpto CHOCO
# creado 1239247 => SORA en el dpto BOYACA
# creado 1239248 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 1239249 => MAHATES en el dpto BOLIVAR
# creado 1239250 => FONSECA en el dpto LA GUAJIRA
# creado 1239251 => CHOCONTA en el dpto CUNDINAMARCA
# creado 1239252 => SOPETRAN en el dpto ANTIOQUIA
# creado 1239253 => MOSQUERA en el dpto CUNDINAMARCA
# creado 1239254 => CERRO SAN ANTONIO en el dpto MAGDALENA
# creado 1239255 => PUERTO ESCONDIDO en el dpto CORDOBA
# creado 1239256 => MITU en el dpto VAUPES
# creado 1239257 => PUERTO  LEGUIZAMO en el dpto PUTUMAYO
# creado 1239258 => SAN JOSE DE PARE en el dpto BOYACA
# creado 1239259 => ROBERTO PAYAN en el dpto NARINO
# creado 1239260 => FUNZA en el dpto CUNDINAMARCA
# creado 1239261 => LA CUMBRE en el dpto VALLE
# creado 1239262 => ALBANIA en el dpto LA GUAJIRA
# creado 1239263 => VALLEDUPAR en el dpto CESAR
# creado 1239264 => SAN ANTERO en el dpto CORDOBA
# creado 1239265 => TESALIA en el dpto HUILA
# creado 1239266 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1239267 => LA CALERA en el dpto CUNDINAMARCA
# creado 1239268 => TIBIRITA en el dpto CUNDINAMARCA
# creado 1239269 => PASTO en el dpto NARINO
# creado 1239270 => LA PAZ  ROBLES en el dpto CESAR
# creado 1239271 => POPAYAN en el dpto CAUCA
# creado 1239272 => VILLANUEVA en el dpto CASANARE
# creado 1239273 => PEQUE en el dpto ANTIOQUIA
# creado 1239274 => DABEIBA en el dpto ANTIOQUIA
# creado 1239275 => MEDELLIN en el dpto ANTIOQUIA
# creado 1239276 => GALERAS en el dpto SUCRE
# creado 1239277 => SAHAGUN en el dpto CORDOBA
# creado 1239278 => FLORIDABLANCA en el dpto SANTANDER
# creado 1239279 => CALOTO en el dpto CAUCA
# creado 1239280 => EL CARMEN en el dpto CHOCO
# creado 1239281 => PASTO en el dpto NARINO
# creado 1239282 => LA VEGA en el dpto CAUCA
# creado 1239283 => SALAMINA en el dpto MAGDALENA
# creado 1239284 => ARAUCA en el dpto ARAUCA
# creado 1239285 => CALAMAR en el dpto GUAVIARE
# creado 1239286 => ESPINAL en el dpto TOLIMA
# creado 1239287 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 1239288 => BARRANCABERMEJA en el dpto SANTANDER
# creado 1239289 => SAN AGUSTIN en el dpto HUILA
# creado 1239290 => EL CARMEN en el dpto NORTE DE SANTANDER
# creado 1239291 => GIRON en el dpto SANTANDER
# creado 1239292 => BARRANQUILLA en el dpto ATLANTICO
# creado 1239293 => CIENAGA DE ORO en el dpto CORDOBA
# creado 1239294 => TOLUVIEJO en el dpto SUCRE
# creado 1239295 => MARGARITA en el dpto BOLIVAR
# creado 1239296 => FRONTINO en el dpto ANTIOQUIA
# creado 1239297 => POPAYAN en el dpto CAUCA
# creado 1239298 => SAN GIL en el dpto SANTANDER
# creado 1239299 => FLORIDA en el dpto VALLE
# creado 1239300 => GACHETA en el dpto CUNDINAMARCA
# creado 1239301 => ISNOS en el dpto HUILA
# creado 1239302 => TURBACO en el dpto BOLIVAR
# creado 1239303 => PLANETA RICA en el dpto CORDOBA
# creado 1239304 => FOMEQUE en el dpto CUNDINAMARCA
# creado 1239305 => GALAPA en el dpto ATLANTICO
# creado 1239306 => MALAGA en el dpto SANTANDER
# creado 1239307 => CONDOTO en el dpto CHOCO
# creado 1239308 => TADO en el dpto CHOCO
# creado 1239309 => PUERTO CARRENO en el dpto VICHADA
# creado 1239310 => COTORRA en el dpto CORDOBA
# creado 1239311 => GRANADA en el dpto CUNDINAMARCA
# creado 1239312 => SANTACRUZ en el dpto NARINO
# creado 1239313 => VILLAVICENCIO en el dpto META
# creado 1239314 => SANTA ISABEL en el dpto TOLIMA
# creado 1239315 => IBAGUE en el dpto TOLIMA
# creado 1239316 => CHIMA en el dpto SANTANDER
# creado 1239317 => SURATA en el dpto SANTANDER
# creado 1239318 => PUERTO ESCONDIDO en el dpto CORDOBA
# creado 1239319 => NARIÑO en el dpto CUNDINAMARCA
# creado 1239320 => ACANDI en el dpto CHOCO
# creado 1239321 => LA UNION en el dpto SUCRE
# creado 1239322 => BARRANCABERMEJA en el dpto SANTANDER
# creado 1239323 => CORDOBA en el dpto QUINDIO
# creado 1239324 => PACORA en el dpto CALDAS
# creado 1239325 => TENERIFE en el dpto MAGDALENA
# creado 1239326 => FLANDES en el dpto TOLIMA
# creado 1239327 => SAN JACINTO en el dpto BOLIVAR
# creado 1239328 => TIMBIQUI en el dpto CAUCA
# creado 1239329 => SANTA MARTA en el dpto MAGDALENA

# %%
revisar_contenido_de_una_tabla("Municipio",'','',10,'nombre_Municipio')
# Out:
# Total de registros en la tabla Municipio: 1124
# SELECT * FROM Municipio ORDER BY nombre_Municipio ASC LIMIT 10
# (220, 'ABEJORRAL', 17)
# (175, 'ABREGO', 14)
# (10901, 'ABRIAQUI', 17)
# (123, 'ACACIAS', 15)
# (6881, 'ACANDI', 25)
# (1183, 'ACEVEDO', 9)
# (412, 'ACHI', 26)
# (1058, 'AGRADO', 9)
# (136, 'AGUA DE DIOS', 16)
# (761, 'AGUACHICA', 11)

# %% [markdown]
# ## 5.4 cargar EPS

# %%
def cargar_datos_eps(df,db_path,regimen="Contributivo"):
 conn= sqlite3.connect(db_path)
 cursor=conn.cursor()
 total_creados=0
 valores_unicos = df[['Código de la entidad','Nombre de la entidad']].drop_duplicates()
 for index,row in valores_unicos.iterrows():
  codigo_eps= row['Código de la entidad']
  nombre_eps= row['Nombre de la entidad']
  try:
    cursor.execute("INSERT OR IGNORE INTO Eps (codigo_Eps, Nombre_Eps, Regimen) VALUES (?, ?,?)", (codigo_eps, nombre_eps,regimen))
    total_creados+=1
    print(f"creado {total_creados} => {nombre_eps} con el código {codigo_eps}")
  except sqlite3.IntegrityError as e:
    print(f"No fue posible crear la EPS {nombre_eps} con el código {codigo_eps} due to {e}")
    pass
 conn.commit()
 conn.close()

# %%
cargar_datos_eps(df,db_path)
# Out:
# creado 1 => NUEVA EPS S.A. -CM con el código EPSS37
# creado 2 => COOSALUD EPS S.A. con el código ESS024
# creado 3 => NUEVA EPS S.A. con el código EPSS41
# creado 4 => EMSSANAR S.A.S. con el código ESS118
# creado 5 => CAJACOPI EPS S.A.S con el código CCF055
# creado 6 => CAJA DE COMPENSACION FAMILIAR DEL VALLE DEL CAUCA "COMFENALCO VALLE DE LA GENTE" -CM con el código EPSS12
# creado 7 => SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGIMEN CONTRIBUTIVO Y DEL REGIMEN SUBSIDIADO S.A. -CM con el código EPSS02
# creado 8 => EPS FAMISANAR S.A.S. -CM con el código EPSS17
# creado 9 => EPS FAMILIAR DE COLOMBIA S.A.S. con el código CCF033
# creado 10 => ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ENTIDAD PROMOTORA DE SALUD - MUTUAL SER EPS con el código ESS207
# creado 11 => CAJA DE COMPENSACIÓN FAMILIAR DEL ORIENTE COLOMBIANO "COMFAORIENTE con el código CCF050
# creado 12 => ASOCIACIÓN INDÍGENA DEL CAUCA A.I.C. EPSI con el código EPSI03
# creado 13 => ALIANZA MEDELLIN ANTIOQUIA EPS S.A.S. "SAVIA SALUD EPS con el código EPSS40
# creado 14 => ENTIDAD PROMOTORA DE SALUD SANITAS S.A.S. -CM con el código EPSS05
# creado 15 => CAPITAL SALUD ENTIDAD PROMOTORA DE SALUD DEL RÉGIMEN SUBSIDIADO SAS "CAPITAL SALUD EPS-S S.A.S. con el código EPSS34
# creado 16 => CAJA DE COMPENSACIÓN FAMILIAR COMPENSAR -CM con el código EPSS08
# creado 17 => COOSALUD EPS S.A. -CM con el código EPSS42
# creado 18 => ASMET SALUD EPS S.A.S. con el código ESS062
# creado 19 => EPS SURAMERICANA S.A. -CM con el código EPSS10
# creado 20 => ASOCIACIÓN DE CABILDOS INDÍGENAS DEL CESAR Y GUAJIRA "DUSAKAWI A.R.S.I. con el código EPSI01
# creado 21 => ENTIDAD PROMOTORA DE SALUD MALLAMAS EPSI con el código EPSI05
# creado 22 => PIJAOS SALUD EPSI con el código EPSI06
# creado 23 => ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ENTIDAD PROMOTORA DE SALUD - MUTUAL SER EPS -CM con el código EPSS48
# creado 24 => ENTIDAD PROMOTORA DE SALUD SERVICIO OCCIDENTAL DE SALUD S.A. S.O.S. -CM con el código EPSS18
# creado 25 => CAPRESOCA E.P.S. con el código EPS025
# creado 26 => EMPRESA PROMOTORA DE SALUD INDÍGENA ANAS WAYUU EPSI con el código EPSI04
# creado 27 => CAJA DE COMPENSACIÓN FAMILIAR DEL CHOCÓ con el código CCF102
# creado 28 => FUNDACIÓN SALUD MIA -CM con el código EPSS46
# creado 29 => ALIANSALUD EPS S.A. -CM con el código EPSS01
# creado 30 => FUNDACIÓN SALUD MIA con el código EPSS49

# %%
revisar_contenido_de_una_tabla("Municipio",'','',10,'nombre_Municipio')
# Out:
# Total de registros en la tabla Municipio: 1124
# SELECT * FROM Municipio ORDER BY nombre_Municipio ASC LIMIT 10
# (220, 'ABEJORRAL', 17)
# (175, 'ABREGO', 14)
# (10901, 'ABRIAQUI', 17)
# (123, 'ACACIAS', 15)
# (6881, 'ACANDI', 25)
# (1183, 'ACEVEDO', 9)
# (412, 'ACHI', 26)
# (1058, 'AGRADO', 9)
# (136, 'AGUA DE DIOS', 16)
# (761, 'AGUACHICA', 11)

# %% [markdown]
# ## 5.5 crear tabla nieta "detalle"
# ---

# %%
conn= sqlite3.connect(db_path)
cursor=conn.cursor()
cursor.execute('''
CREATE TABLE IF NOT EXISTS Detalle (
    Id_Detalle INTEGER PRIMARY KEY AUTOINCREMENT,
    Id_Municipio INTEGER,
    Id_Sisben INTEGER,
    codigo_Eps TEXT,
    Genero TEXT,
    Grupo_etario TEXT,
    Tipo_afiliado TEXT,
    Estado_afiliado TEXT,
    Condicion_beneficiario TEXT,
    Regimen TEXT,
    Zona_afiliacion TEXT,
    Cantidad_registros INTEGER,
    FOREIGN KEY (Id_Municipio) REFERENCES Municipio(Id_Municipio),
    FOREIGN KEY (Id_Sisben) REFERENCES Sisben(Id_Sisben),
    FOREIGN KEY (codigo_Eps) REFERENCES Eps(codigo_Eps)
)
''')
conn.commit()
conn.close()

# %%
def cargar_detalle(df,db_path):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  total_creados=0
  for index,row in df.iterrows():
    municipio   =row['Municipio']
    departamento=row['Departamento']
    #--------para obtener el id del sisben
    if (pd.isna(row['Nivel del Sisbén'])):
      id_sisben=6 # Asumimos 'nan' tiene el id 6 de la tabla Sisben
    else:
      sisben=row['Nivel del Sisbén']
      cursor.execute("SELECT Id_Sisben FROM Sisben WHERE Nombre_Sisben=?", (sisben,))
      sisben_id=cursor.fetchone()
      if sisben_id:
        id_sisben=sisben_id[0]
      else:
        print(f"ERRROR: Sisben {sisben} para el municipio {municipio} no encontrado")
        id_sisben = None # Handle case where sisben is not found
    #----------para obtener id del municipio
    cursor.execute("SELECT Id_Municipio FROM Municipio WHERE Nombre_Municipio=? AND Id_Departamento=(SELECT Id_Departamento FROM Departamento WHERE Nombre_Departamento=?)", (municipio,departamento))
    municipio_id=cursor.fetchone()
    if municipio_id:
      municipio_id=municipio_id[0]
    else:
      print(f"ERRROR: Municipio {municipio} para el departamento {departamento} no encontrado")
      municipio_id = None # Handle case where municipio is not found
    #--------------guarde cada registro en la tabla---
    try:
      cursor.execute('''
      INSERT INTO Detalle (Id_Municipio, Id_Sisben, codigo_Eps, Genero, Grupo_etario, Tipo_afiliado, Estado_afiliado, Condicion_beneficiario, Regimen, Zona_afiliacion, Cantidad_registros)
      VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                    (municipio_id,
                      id_sisben,
                      row['Código de la entidad'],
                      row['Genero'],
                      row['Grupo_etario'],
                      row['Tipo de afiliado'],
                      row['Estado del afiliado'],
                      row['Condición del beneficiario'],
                      row['Régimen al que pertenece'],
                      row['Zona de Afiliación'],
                      row['cantidad']
                    ))
      total_creados+=1
      # print(f"creado {total_creados}") # Commented out to avoid excessive output
    except sqlite3.IntegrityError as e:
      print(f"No fue posible crear el registro due to {e}")
      pass
  conn.commit()
  conn.close()

# %%
print("Original df columns:", df.columns.tolist())
temp_df = df.copy()
# Rename 'Grupo etario' to 'Grupo_etario' to avoid potential Unicode issues
# Let's ensure the exact original column name is used
actual_grupo_etario_col = None
for col in df.columns:
    if 'Grupo' in col and 'etario' in col and ' ' in col:
        actual_grupo_etario_col = col
        break

if actual_grupo_etario_col:
    temp_df = temp_df.rename(columns={actual_grupo_etario_col: 'Grupo_etario'})
    print(f"Column '{actual_grupo_etario_col}' renamed to 'Grupo_etario'. New temp_df columns: {temp_df.columns.tolist()}")
else:
    print("Could not find 'Grupo etario' column in df.")

cargar_detalle(temp_df, db_path)
# Out:
# Original df columns: ['Genero', 'Grupo etario ', 'Código de la entidad', 'Nombre de la entidad', 'Régimen al que pertenece', 'Tipo de afiliado', 'Estado del afiliado', 'Condición del beneficiario', 'Zona de Afiliación', 'Departamento', 'Municipio', 'Nivel del Sisbén', 'Grupo poblacional del afiliado', 'cantidad']
# Column 'Grupo etario ' renamed to 'Grupo_etario'. New temp_df columns: ['Genero', 'Grupo_etario', 'Código de la entidad', 'Nombre de la entidad', 'Régimen al que pertenece', 'Tipo de afiliado', 'Estado del afiliado', 'Condición del beneficiario', 'Zona de Afiliación', 'Departamento', 'Municipio', 'Nivel del Sisbén', 'Grupo poblacional del afiliado', 'cantidad']

# %%
revisar_contenido_de_una_tabla("Detalle",'','',10)
# Out:
# Total de registros en la tabla Detalle: 1239329
# SELECT * FROM Detalle LIMIT 10
# (1, 1, 1, 'EPSS37', 'Femenino', '15 a 19', 'BENEFICIARIO', 'Activo', 'NO APLICA', 'Subsidiado', 'Rural', 15)
# (2, 2, 1, 'ESS024', 'Femenino', '19 a 45', 'BENEFICIARIO', 'Activo', 'DISCAPACIDAD', 'Subsidiado', 'Urbana-Cabecera Municipal', 1)
# (3, 3, 2, 'EPSS37', 'Masculino', '55 a 60', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Urbana-Cabecera Municipal', 1)
# (4, 4, 2, 'EPSS37', 'Femenino', '50 a 55', 'BENEFICIARIO', 'Activo', 'NO APLICA', 'Subsidiado', 'Rural', 1)
# (5, 5, 1, 'EPSS37', 'Masculino', '15 a 19', 'BENEFICIARIO', 'Activo', 'NO APLICA', 'Subsidiado', 'Urbana', 21)
# (6, 6, 1, 'EPSS37', 'Femenino', '19 a 45', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Rural - Dispersal', 1)
# (7, 7, 2, 'EPSS41', 'Femenino', '45 a 50', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Rural', 23)
# (8, 8, 3, 'EPSS41', 'Femenino', '5 a 15', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Urbana-Cabecera Municipal', 1)
# (9, 9, 4, 'ESS118', 'Masculino', '45 a 50', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Urbana', 7)
# (10, 10, 4, 'CCF055', 'Femenino', '5 a 15', 'CABEZA DE FAMILIA', 'Activo', 'NO APLICA', 'Subsidiado', 'Urbana-Cabecera Municipal', 7)

# %% [markdown]
# # 6.Integrar con tutelas radicadas

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

url_forder_csv="/content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/DataSets_TMP/tutelas_2021_al_2025"

# Check if the directory exists, and create it if it doesn't
if not os.path.exists(url_forder_csv):
  print(f"The directory {url_forder_csv} does not exist. Creating it now...")
  os.makedirs(url_forder_csv)
  print(f"Directory {url_forder_csv} created.")
else:
  print(f"The directory {url_forder_csv} already exists.")

listado_archivos= [f for f in os.listdir(url_forder_csv) if f.endswith(".csv")]
print(listado_archivos)

columnas_nombre=[
    "clasificacion",
    "num_expediente",
    "fecha_Radica",
    "demandante",
    "demandado",
    "primera_instancia",
    "segunda_instancia",
    "num_23Digitos",
    "providencia",
    "fechaSentencia"
]
df_tutelas=pd.DataFrame(columns=columnas_nombre)
display (df_tutelas)
# Out:
# The directory /content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/DataSets_TMP/tutelas_2021_al_2025 does not exist. Creating it now...
# Directory /content/drive/MyDrive/UniversidadCentral/Maestría_en_Analítica_de_Datos/Bigdata/DataSets_TMP/tutelas_2021_al_2025 created.
# []
# Empty DataFrame
# Columns: [clasificacion, num_expediente, fecha_Radica, demandante, demandado, primera_instancia, segunda_instancia, num_23Digitos, providencia, fechaSentencia]
# Index: []

# %%
def cargar_data_desde_archivo_csv(ruta_archivo):
  try:
      df_temporal = pd.read_csv(ruta_archivo,sep=';',header=None,encoding='latin-1',on_bad_lines='skip')
      #agregarle nombre de columnas al df creado
      df_temporal.columns=columnas_nombre
      if (len(df_temporal.columns)==len(columnas_nombre)):
        print(f" archivo {os.path.basename(ruta_archivo)} cargada exitosamente")
        return df_temporal
      else:
        print(f"archivo no trabajado {os.path.basename(ruta_archivo)} no tiene 10 columnas")
        return None

  except Exception as e:
      print(f"Error al procesar el archivo {os.path.basename(ruta_archivo)}: {str(e)}")
      return None

# %%
df_list=[]  #lista de df resultante de los datos de cada uno de los CSV
with ThreadPoolExecutor() as executor:
  future_to_file= {executor.submit(cargar_data_desde_archivo_csv,os.path.join(url_forder_csv,archivo_nombre)):archivo_nombre for archivo_nombre in listado_archivos}
  for future in as_completed(future_to_file):
    df=future.result()
    if df is not None:
      df_list.append(df)
#--------una vez termine de cargar todos los CSV combinelos en el dataframa df_tutelas
if df_list:
  df_tutelas= pd.concat(df_list,ignore_index=True)
  # reemplazar las palabras "NULL" por none
  df_tutelas.replace("NULL",None,inplace=True)
  display(df_tutelas.head())

# %%
df_tutelas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   clasificacion      0 non-null      object
#  1   num_expediente     0 non-null      object
#  2   fecha_Radica       0 non-null      object
#  3   demandante         0 non-null      object
#  4   demandado          0 non-null      object
#  5   primera_instancia  0 non-null      object
#  6   segunda_instancia  0 non-null      object
#  7   num_23Digitos      0 non-null      object
#  8   providencia        0 non-null      object
#  9   fechaSentencia     0 non-null      object
# dtypes: object(10)
# memory usage: 132.0+ bytes

# %% [markdown]
# ## 6.1 extraer los expedientes donde los demandados "eps"

# %%
df_tutelas_eps=df_tutelas[df_tutelas['demandado'].str.contains("EPS",na=False)]
display(df_tutelas_eps.head())
df_tutelas_eps.count()
# Out:
# Empty DataFrame
# Columns: [clasificacion, num_expediente, fecha_Radica, demandante, demandado, primera_instancia, segunda_instancia, num_23Digitos, providencia, fechaSentencia]
# Index: []
# clasificacion        0
# num_expediente       0
# fecha_Radica         0
# demandante           0
# demandado            0
# primera_instancia    0
# segunda_instancia    0
# num_23Digitos        0
# providencia          0
# fechaSentencia       0
# dtype: int64

# %% [markdown]
# ## 6.2 Extraer las EPS dbua.db (sqlite)

# %%
conn= sqlite3.connect(db_path)
df_eps=pd.read_sql_query("SELECT * FROM Eps",conn)
conn.close()
display(df_eps.head())
# Out:
#   codigo_Eps          Nombre_Eps       regimen
# 0     EPSS37  NUEVA EPS S.A. -CM  Contributivo
# 1     ESS024   COOSALUD EPS S.A.  Contributivo
# 2     EPSS41      NUEVA EPS S.A.  Contributivo
# 3     ESS118     EMSSANAR S.A.S.  Contributivo
# 4     CCF055  CAJACOPI EPS S.A.S  Contributivo

# %% [markdown]
# ## 6.3 contar las tutelas en contra de cada EPS (df_eps)

# %%
df_eps['total_tutelas']=0
demandados_encontrados =set()
for index,row in df_eps.iterrows():
  eps_nombre=row['Nombre_Eps']
  matching_tutelas = df_tutelas_eps[df_tutelas_eps['demandado'].str.contains(eps_nombre,na=False,case=False)]  #mejorar el código "NUEVA EPS"
  total_tutelas=matching_tutelas.shape[0]
  #df_eps.at[index,'total_tutelas']=total_tutelas
  df_eps.loc[index,'total_tutelas']=total_tutelas
  demandados_encontrados.update(matching_tutelas['demandado'].tolist())

demandados_no_encontrados=set(df_tutelas_eps['demandado'].unique())-demandados_encontrados
print(f"EPS demandadas encontrados: {len(demandados_encontrados)}")
print(f"EPS demandadas NO encontradas: {len(demandados_no_encontrados)}")
for demandado in demandados_no_encontrados:
  print(demandado)
# Out:
# EPS demandadas encontrados: 0
# EPS demandadas NO encontradas: 0

# %%
display(df_eps.head())
# Out:
#   codigo_Eps          Nombre_Eps       regimen  total_tutelas
# 0     EPSS37  NUEVA EPS S.A. -CM  Contributivo              0
# 1     ESS024   COOSALUD EPS S.A.  Contributivo              0
# 2     EPSS41      NUEVA EPS S.A.  Contributivo              0
# 3     ESS118     EMSSANAR S.A.S.  Contributivo              0
# 4     CCF055  CAJACOPI EPS S.A.S  Contributivo              0
